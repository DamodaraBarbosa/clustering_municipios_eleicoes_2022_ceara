# %% [markdown]
# <a href="https://colab.research.google.com/github/DamodaraBarbosa/eleicoes_ceara_2022/blob/main/08_1%C2%BA_turno_presidente_eleicoes_ceara_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalação das bibliotecas `geopandas`, `geobr` e `descartes`

# %%
# !pip install geopandas geobr descartes
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: geobr in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: descartes in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descartes) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (1.22.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=2.2.0->geopandas) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (8.1.4)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (3.1.0)

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from geobr import read_municipality
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
# Para ignorar qualquer aviso:

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Carregamento dos dados no *dataframe*

# %%
# Os dados da eleição presidencial são carregados:

votos_presidente = pd.read_csv(
    '/content/drive/MyDrive/Datasets/votacao_secao_2022_BR.csv',
    encoding= 'latin-1', sep= ';'
)

# E visualizados:

votos_presidente.head(2)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  04/10/2022   21:02:14         2022                2  ELEIÇÃO ORDINÁRIA
# 1  04/10/2022   21:02:14         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 0         1         544  ELEIÇÃO GERAL FEDERAL 2022  02/10/2022
# 1         1         544  ELEIÇÃO GERAL FEDERAL 2022  02/10/2022
#
#   TP_ABRANGENCIA  ... NM_MUNICIPIO NR_ZONA NR_SECAO  CD_CARGO    DS_CARGO  \
# 0              F  ...    EUNÁPOLIS     188      319         1  PRESIDENTE
# 1              F  ...   CHAPADINHA      42      169         1  PRESIDENTE
#
#    NR_VOTAVEL           NM_VOTAVEL  QT_VOTOS NR_LOCAL_VOTACAO  SQ_CANDIDATO
# 0          15  SIMONE NASSAR TEBET         6             1694  280001607833
# 1          15  SIMONE NASSAR TEBET         1             1864  280001607833
#
# [2 rows x 24 columns]

# %%
# Selecionam-se apenas os dados referentes ao estado do Ceará e ao 1º turno da eleição:

presidente = votos_presidente.query('SG_UF == "CE" and NR_TURNO == 1')

presidente.head(2)
# Out:
#     DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 30  04/10/2022   21:02:14         2022                2  ELEIÇÃO ORDINÁRIA
# 65  04/10/2022   21:02:14         2022                2  ELEIÇÃO ORDINÁRIA
#
#     NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 30         1         544  ELEIÇÃO GERAL FEDERAL 2022  02/10/2022
# 65         1         544  ELEIÇÃO GERAL FEDERAL 2022  02/10/2022
#
#    TP_ABRANGENCIA  ... NM_MUNICIPIO NR_ZONA NR_SECAO  CD_CARGO    DS_CARGO  \
# 30              F  ...    FORTALEZA       3      503         1  PRESIDENTE
# 65              F  ...      PARAMBU      19      395         1  PRESIDENTE
#
#     NR_VOTAVEL           NM_VOTAVEL  QT_VOTOS NR_LOCAL_VOTACAO  SQ_CANDIDATO
# 30          15  SIMONE NASSAR TEBET         7             2259  280001607833
# 65          15  SIMONE NASSAR TEBET         2             1716  280001607833
#
# [2 rows x 24 columns]

# %% [markdown]
# # 2. Informações do *dataframe*

# %% [markdown]
# ## 2.1 Dimensões do *dataframe*

# %%
f'O dataframe possui {presidente.shape[0]} linhas em {presidente.shape[1]} colunas.'
# Out:
# 'O dataframe possui 154686 linhas em 24 colunas.'

# %% [markdown]
# ## 2.2 Infos do *dataframe*

# %%
presidente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154686 entries, 30 to 3529834
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DT_GERACAO        154686 non-null  object
#  1   HH_GERACAO        154686 non-null  object
#  2   ANO_ELEICAO       154686 non-null  int64
#  3   CD_TIPO_ELEICAO   154686 non-null  int64
#  4   NM_TIPO_ELEICAO   154686 non-null  object
#  5   NR_TURNO          154686 non-null  int64
#  6   CD_ELEICAO        154686 non-null  int64
#  7   DS_ELEICAO        154686 non-null  object
#  8   DT_ELEICAO        154686 non-null  object
#  9   TP_ABRANGENCIA    154686 non-null  object
#  10  SG_UF             154686 non-null  object
#  11  SG_UE             154686 non-null  object
#  12  NM_UE             154686 non-null  object
#  13  CD_MUNICIPIO      154686 non-null  int64
#  14  NM_MUNICIPIO      154686 non-null  object
#  15  NR_ZONA           154686 non-null  int64
#  16  NR_SECAO          154686 non-null  int64
#  17  CD_CARGO          154686 non-null  int64
#  18  DS_CARGO          154686 non-null  object
#  19  NR_VOTAVEL        154686 non-null  int64
#  20  NM_VOTAVEL        154686 non-null  object
#  21  QT_VOTOS          154686 non-null  int64
#  22  NR_LOCAL_VOTACAO  154686 non-null  int64
#  23  SQ_CANDIDATO      154686 non-null  int64
# dtypes: int64(12), object(12)
# memory usage: 29.5+ MB

# %% [markdown]
# ## 2.3 Dados faltantes

# %% [markdown]
# É importante verificar a presença de dados faltantes no conjunto de dados, portanto:

# %%
presidente.isnull().sum()
# Out:
# DT_GERACAO          0
# HH_GERACAO          0
# ANO_ELEICAO         0
# CD_TIPO_ELEICAO     0
# NM_TIPO_ELEICAO     0
# NR_TURNO            0
# CD_ELEICAO          0
# DS_ELEICAO          0
# DT_ELEICAO          0
# TP_ABRANGENCIA      0
# SG_UF               0
# SG_UE               0
# NM_UE               0
# CD_MUNICIPIO        0
# NM_MUNICIPIO        0
# NR_ZONA             0
# NR_SECAO            0
# CD_CARGO            0
# DS_CARGO            0
# NR_VOTAVEL          0
# NM_VOTAVEL          0
# QT_VOTOS            0
# NR_LOCAL_VOTACAO    0
# SQ_CANDIDATO        0
# dtype: int64

# %% [markdown]
# > Não há dados faltantes no conjunto de dados.

# %% [markdown]
# ## 2.4 Dados duplicados

# %%
presidente.loc[presidente.duplicated()]
# Out:
# Empty DataFrame
# Columns: [DT_GERACAO, HH_GERACAO, ANO_ELEICAO, CD_TIPO_ELEICAO, NM_TIPO_ELEICAO, NR_TURNO, CD_ELEICAO, DS_ELEICAO, DT_ELEICAO, TP_ABRANGENCIA, SG_UF, SG_UE, NM_UE, CD_MUNICIPIO, NM_MUNICIPIO, NR_ZONA, NR_SECAO, CD_CARGO, DS_CARGO, NR_VOTAVEL, NM_VOTAVEL, QT_VOTOS, NR_LOCAL_VOTACAO, SQ_CANDIDATO]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# > Também não há dados duplicados no conjunto de dados.

# %% [markdown]
# # 3. Tratamento dos dados

# %% [markdown]
# ## 3.1 Seleção das colunas de interesse

# %% [markdown]
# Nem toda coluna do *dataframe* é de interesse na análise, na base de dados, por exemplo, há colunas com valores que se repetem em todas as linhas. Além disso, sabe-se que é uma análise do 1º turno da eleição presidencial, dos municípios cearenses, ou seja, há que colunas que não são relevantes. As colunas selecionadas são:

# %%
presidente = presidente[['NM_MUNICIPIO', 'NR_ZONA', 'NR_SECAO', 'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS']]
presidente.head(2)
# Out:
#    NM_MUNICIPIO  NR_ZONA  NR_SECAO  NR_VOTAVEL           NM_VOTAVEL  QT_VOTOS
# 30    FORTALEZA        3       503          15  SIMONE NASSAR TEBET         7
# 65      PARAMBU       19       395          15  SIMONE NASSAR TEBET         2

# %% [markdown]
# ## 3.2 Renomeação das colunas

# %% [markdown]
# Por questões estéticas e de boas práticas os nomes das colunas são colocadas em letras minúsculas.

# %%
# As colunas são renomeadas:

presidente = presidente.rename({'NM_MUNICIPIO': 'nm_municipio', 'NR_ZONA': 'nr_zona',
                                'NR_SECAO': 'nr_secao', 'NR_VOTAVEL': 'nr_votavel',
                                'NM_VOTAVEL': 'nm_votavel', 'QT_VOTOS': 'qt_votos'}, axis= 1)
presidente. head(2)
# Out:
#    nm_municipio  nr_zona  nr_secao  nr_votavel           nm_votavel  qt_votos
# 30    FORTALEZA        3       503          15  SIMONE NASSAR TEBET         7
# 65      PARAMBU       19       395          15  SIMONE NASSAR TEBET         2

# %% [markdown]
# ## 3.3 Mudança do tipo de dado das colunas `nr_zona` e `nr_secao`

# %% [markdown]
# Apesar de serem valores numéricos, os dados das colunas `nr_zona` e `nr_secao` são categóricos já que representam zonas e seções eleitorais.

# %%
# Conversão dos dados das colunas para tipo string:

presidente['nr_zona'] = presidente['nr_zona'].astype(str)
presidente['nr_secao'] = presidente['nr_secao'].astype(str)

# %%
presidente.dtypes
# Out:
# nm_municipio    object
# nr_zona         object
# nr_secao        object
# nr_votavel       int64
# nm_votavel      object
# qt_votos         int64
# dtype: object

# %% [markdown]
# # 4. Análise da eleição para presidente no estado do Ceará

# %% [markdown]
# ## 4.1 Candidatos

# %%
presidente['nm_votavel'].unique()
# Out:
# array(['SIMONE NASSAR TEBET', 'JAIR MESSIAS BOLSONARO',
#        'KELMON LUIS DA SILVA SOUZA', 'VOTO NULO',
#        'LUIZ INÁCIO LULA DA SILVA', 'CIRO FERREIRA GOMES', 'VOTO BRANCO',
#        'VERA LUCIA PEREIRA DA SILVA SALGADO', 'SORAYA VIEIRA THRONICKE',
#        'LUIZ FELIPE CHAVES D AVILA', 'SOFIA PADUA MANZANO',
#        'LEONARDO PÉRICLES VIEIRA ROQUE', 'JOSE MARIA EYMAEL'],
#       dtype=object)

# %% [markdown]
# ## 4.2 Votos por candidato

# %%
# Os votos dos candidatos são somados e o dataframe é organizado em ordem decrescente de votos:

votos_por_candidato = presidente.groupby('nm_votavel')['qt_votos'].sum().to_frame().sort_values('qt_votos', ascending= False)

# %%
fig = px.bar(
    data_frame= votos_por_candidato,
    y= votos_por_candidato.index, text= 'qt_votos',
    x= 'qt_votos', color= votos_por_candidato.index,
    title= 'Votos nos candidatos à presidência no estado do Ceará'
)
fig.update_xaxes(range= [0, 4e6])
fig.update_traces(textfont_size= 12, textposition= 'outside')
fig.update_layout(title= dict(x= 0.5), yaxis_title= 'Candidatos', xaxis_title= 'Quantidade de votos', showlegend= False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a8c9bf45-42d7-46ae-b264-8707ea550882" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8c9bf45-42d7-46ae-b264-8707ea550882")) {                    Plotly.newPlot(                        "a8c9bf45-42d7-46ae-b264-8707ea550882",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"text":[3578355.0],"textposition":"outside","x":[3578355],"xaxis":"x","y":["LUIZ IN\u00c1CIO LULA DA SILVA"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"text":[1377827.0],"textposition":"outside","x":[1377827],"xaxis":"x","y":["JAIR MESSIAS BOLSONARO"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"text":[369222.0],"textposition":"outside","x":[369222],"xaxis":"x","y":["CIRO FERREIRA GOMES"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"text":[127100.0],"textposition":"outside","x":[127100],"xaxis":"x","y":["VOTO NULO"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"text":[72246.0],"textposition":"outside","x":[72246],"xaxis":"x","y":["VOTO BRANCO"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"text":[66214.0],"textposition":"outside","x":[66214],"xaxis":"x","y":["SIMONE NASSAR TEBET"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"SORAYA VIEIRA THRONICKE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SORAYA VIEIRA THRONICKE","offsetgroup":"SORAYA VIEIRA THRONICKE","orientation":"h","showlegend":true,"text":[24497.0],"textposition":"outside","x":[24497],"xaxis":"x","y":["SORAYA VIEIRA THRONICKE"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"LUIZ FELIPE CHAVES D AVILA","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"LUIZ FELIPE CHAVES D AVILA","offsetgroup":"LUIZ FELIPE CHAVES D AVILA","orientation":"h","showlegend":true,"text":[7030.0],"textposition":"outside","x":[7030],"xaxis":"x","y":["LUIZ FELIPE CHAVES D AVILA"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alig ...

# %% [markdown]
# Os candidatos mais votados foram:
#
# > * **1º:** Luis Inácio Lula da Silva (Candidato eleito) 🥇
# > * **2º:** Jair Messias Bolsonaro 🥈
# > * **3º:** Ciro Ferreira Gomes 🥉
# >
# > Os demais candidatos receberam menos votos que **VOTO BRANCO e NULO.**

# %% [markdown]
# ## 4.3 Porcentagem dos votos totais e válidos

# %%
# Excetuam-se os votos brancos e nulos:

votos_validos = presidente.query('nm_votavel != ["VOTO NULO", "VOTO BRANCO"]')

# Calcula-se apenas os votos válidos:

total_votos_validos = votos_validos['qt_votos'].sum()
print(f'Votos válidos: {total_votos_validos}')

# Votos totais incluindo brancos e nulos:

total_votos = presidente['qt_votos'].sum()
print(f'Votos totais: {total_votos}')
# Out:
# Votos válidos: 5429264
# Votos totais: 5628610

# %%
votos_validos['nm_votavel'].unique()
# Out:
# array(['SIMONE NASSAR TEBET', 'JAIR MESSIAS BOLSONARO',
#        'KELMON LUIS DA SILVA SOUZA', 'LUIZ INÁCIO LULA DA SILVA',
#        'CIRO FERREIRA GOMES', 'VERA LUCIA PEREIRA DA SILVA SALGADO',
#        'SORAYA VIEIRA THRONICKE', 'LUIZ FELIPE CHAVES D AVILA',
#        'SOFIA PADUA MANZANO', 'LEONARDO PÉRICLES VIEIRA ROQUE',
#        'JOSE MARIA EYMAEL'], dtype=object)

# %% [markdown]
# > **VOTO BRANCO e VOTO NULO** foram removidos na variável `votos_validos`.

# %%
# Instancia-se um dataframe contendo a porcentagem de votos totais e votos válidos por candidato ao senado:

porcentagem_votos_presidente = pd.DataFrame(
    {'Votos totais': round((presidente.groupby('nm_votavel')['qt_votos'].sum()/total_votos) * 100, 2), # cálculo da porcentagem de votos totais.
     'Votos válidos': round((votos_validos.groupby('nm_votavel')['qt_votos'].sum()/total_votos_validos) * 100, 2)} # cálculo da porcentagem de votos válidos.
).sort_values(['Votos totais', 'Votos válidos'], ascending= [False, False]) # os dados são ordenados em ordem decrescente.

# Utiliza-se o método transpose para inverter index em colunas e vice-versa:

porcentagem_votos_presidente = porcentagem_votos_presidente.transpose()

porcentagem_votos_presidente
# Out:
# nm_votavel     LUIZ INÁCIO LULA DA SILVA  JAIR MESSIAS BOLSONARO  \
# Votos totais                       63.57                   24.48
# Votos válidos                      65.91                   25.38
#
# nm_votavel     CIRO FERREIRA GOMES  VOTO NULO  VOTO BRANCO  \
# Votos totais                  6.56       2.26         1.28
# Votos válidos                 6.80        NaN          NaN
#
# nm_votavel     SIMONE NASSAR TEBET  SORAYA VIEIRA THRONICKE  \
# Votos totais                  1.18                     0.44
# Votos válidos                 1.22                     0.45
#
# nm_votavel     LUIZ FELIPE CHAVES D AVILA  KELMON LUIS DA SILVA SOUZA  \
# Votos totais                         0.12                        0.04
# Votos válidos                        0.13                        0.04
#
# nm_votavel     SOFIA PADUA MANZANO  LEONARDO PÉRICLES VIEIRA ROQUE  \
# Votos totais                  0.03                            0.02
# Votos válidos                 0.03                            0.02
#
# nm_votavel     JOSE MARIA EYMAEL  VERA LUCIA PEREIRA DA SILVA SALGADO
# Votos totais                0.01                                 0.01
# Votos válidos               0.01                                 0.01

# %%
fig = px.bar(
    data_frame= porcentagem_votos_presidente,
    y= porcentagem_votos_presidente.index,
    x= porcentagem_votos_presidente.columns,
    title= 'Porcentagem dos votos totais e válidos ao cargo de presidente no Ceará'
)
fig.update_layout(
    yaxis= dict(autorange= 'reversed'), xaxis_title= 'Porcentagem dos votos',
    yaxis_title= '', legend_title= 'Candidatos', title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f803f513-6566-4794-9420-d262a3586123" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f803f513-6566-4794-9420-d262a3586123")) {                    Plotly.newPlot(                        "f803f513-6566-4794-9420-d262a3586123",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ IN\u00c1CIO LULA DA SILVA<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[63.57,65.91],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=JAIR MESSIAS BOLSONARO<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"textposition":"auto","x":[24.48,25.38],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=CIRO FERREIRA GOMES<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"textposition":"auto","x":[6.56,6.8],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[2.26,null],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[1.28,null],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SIMONE NASSAR TEBET<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"textposition":"auto","x":[1.18,1.22],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SORAYA VIEIRA THRONICKE<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"SORAYA VIEIRA THRONICKE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SORAYA VIEIRA THRONICKE","offsetgroup":"SORAYA VIEIRA THRONICKE","orientation":"h","showlegend":true,"textposition":"auto","x":[0.44,0.45],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ FELIPE CHAVES D AVILA<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"LUIZ FELIPE CHAVES D AVILA","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"LUIZ FELIPE CHAVES D AVILA","offsetgroup":"LUIZ FELIPE CHAVES D AVILA","orientation":"h","showlegend":true,"textposition":"auto","x":[0.12,0.13],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hov ...

# %% [markdown]
# > * **Luis Inácio Lula da Silva** 🥇: 63,57% dos votos totais e 65,91% dos votos válidos.
# > * **Jair Messias Bolsonaro** 🥈: 24,48% dos votos totais e 25,38% dos votos válidos.
# > * **Ciro Ferreira Gomes** 🥉: 6,56% dos votos totais e 6,80% dos votos válidos.

# %% [markdown]
# ## 4.4 Candidato vencedor por município cearense

# %%
# Os votos nos cadidatos à presidência são determinados:

votos_candidatos_por_municipio = presidente.groupby(['nm_municipio', 'nm_votavel'])['qt_votos'].sum().reset_index()

# Os dados são ordenados em ordem alfabética para os municípios e em ordem decrescente para os votos:

votos_candidatos_por_municipio = votos_candidatos_por_municipio.sort_values(['nm_municipio', 'qt_votos'], ascending= [True, False])

# Seleciona-se apenas o candidato que obteve mais votos em cada município:

vencedores_por_municipio = votos_candidatos_por_municipio.groupby('nm_municipio').head(1)
vencedores_por_municipio.head() # para visualizar o dataframe.
# Out:
#    nm_municipio                 nm_votavel  qt_votos
# 5       ABAIARA  LUIZ INÁCIO LULA DA SILVA      4870
# 17      ACARAPE  LUIZ INÁCIO LULA DA SILVA      5996
# 29       ACARAÚ  LUIZ INÁCIO LULA DA SILVA     24551
# 42     ACOPIARA  LUIZ INÁCIO LULA DA SILVA     23642
# 54       AIUABA  LUIZ INÁCIO LULA DA SILVA      7010

# %%
# Dataframe com dados geoespaciais dos municípios cearenses:

ceara_gpd = read_municipality(code_muni= 23, year= 2020)

# Um pequeno tratamento é feito para que os nomes dos municípios estejam em caixa alta:

ceara_gpd['name_muni'] = ceara_gpd['name_muni'].str.upper()

ceara_gpd.head() # visualização do dataframe.
# Out:
#    code_muni name_muni  code_state abbrev_state name_state  code_region  \
# 0  2300101.0   ABAIARA        23.0           CE      Ceará          2.0
# 1  2300150.0   ACARAPE        23.0           CE      Ceará          2.0
# 2  2300200.0    ACARAÚ        23.0           CE      Ceará          2.0
# 3  2300309.0  ACOPIARA        23.0           CE      Ceará          2.0
# 4  2300408.0    AIUABA        23.0           CE      Ceará          2.0
#
#   name_region                                           geometry
# 0    Nordeste  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...
# 1    Nordeste  MULTIPOLYGON (((-38.65304 -4.15796, -38.65108 ...
# 2    Nordeste  MULTIPOLYGON (((-40.30984 -2.80769, -40.26882 ...
# 3    Nordeste  MULTIPOLYGON (((-39.15631 -5.95731, -39.15267 ...
# 4    Nordeste  MULTIPOLYGON (((-40.11801 -6.34845, -40.11298 ...

# %%
# É feita a união dos dados geoespaciais e os dados referentes aos candidatos vencedores em cada município:

vencedores_por_municipio_gpd = pd.merge(
    left= ceara_gpd[['name_muni', 'geometry']], right= vencedores_por_municipio,
    how= 'left', left_on= 'name_muni', right_on= 'nm_municipio'
)
vencedores_por_municipio_gpd = vencedores_por_municipio_gpd.drop('name_muni', axis= 1) # a coluna é eliminada visto que possui dados redundantes.

# %%
ax = vencedores_por_municipio_gpd.plot(
    'nm_votavel', cmap= 'autumn', legend= True,
    legend_kwds= {'loc': 'upper right'},
    figsize= (12, 10)
)
ax.set_title('Candidato vencedor por município cearense')
plt.show()

# %% [markdown]
# > O candidato eleito **Luiz Inácio Lula da Silva** foi o **mais votado em todos os municípios cearenses.**

# %% [markdown]
# ## 4.5 Votos para presidência nos municípios da Região Metropolitana de Fortaleza

# %% [markdown]
# A Região Metropolitana de Fortaleza é constituída de 19 municípios sendo eles:
#
# > Aquiraz, Cascavel, Caucaia, Chorozinho, Eusébio, Fortaleza, Guaiúba, Horizonte, Itaitinga, Maracanaú, Maranguape, Pacajus, Pacatuba, Pindoretama, São Gonçalo do Amarante, São Luís do Curu, Paraipaba, Paracuru e Trairi.
#
# Fonte: https://pt.wikipedia.org/wiki/Regi%C3%A3o_Metropolitana_de_Fortaleza

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Municípios da Região Metropolitana de Fortaleza:

regiao_metropolitana = [
    'AQUIRAZ', 'CASCAVEL', 'CAUCAIA', 'CHOROZINHO', 'EUSÉBIO',
    'FORTALEZA', 'GUAIÚBA', 'HORIZONTE', 'ITAITINGA', 'MARACANAÚ',
    'MARANGUAPE', 'PACAJUS', 'PACATUBA', 'PINDORETAMA',
    'SÃO GONÇALO DO AMARANTE', 'SÃO LUÍS DO CURU',
    'PARAIPABA', 'PARACURU', 'TRAIRI'
]

# %%
# Buscam-se no conjunto de dados à presidência apenas os municípios da Região Metropolitana de Fortaleza:

presidente_regiao_metropolitana = presidente.query('nm_municipio in @regiao_metropolitana')

# Agrupam-se os dados por município e candidato para determinar os votos:

vencedores_regiao_metropolitana = presidente_regiao_metropolitana.groupby(['nm_municipio', 'nm_votavel'])['qt_votos'].sum().reset_index()

# Os dados são ordenados em ordem alfabética e em ordem decrescente do número de votos:

vencedores_regiao_metropolitana = vencedores_regiao_metropolitana.sort_values(['nm_municipio', 'qt_votos'], ascending= [True, False])

vencedores_regiao_metropolitana.head()
# Out:
#    nm_municipio                 nm_votavel  qt_votos
# 6       AQUIRAZ  LUIZ INÁCIO LULA DA SILVA     31902
# 1       AQUIRAZ     JAIR MESSIAS BOLSONARO     15296
# 0       AQUIRAZ        CIRO FERREIRA GOMES      2605
# 12      AQUIRAZ                  VOTO NULO      1170
# 7       AQUIRAZ        SIMONE NASSAR TEBET       761

# %%
# Instancia-se um dicionário contendo o nº de votos totais ao cargo de senador por município da Região Metropolitana de Fortaleza:

votos_regiao_metropolitana = presidente.groupby('nm_municipio')['qt_votos'].sum()
votos_regiao_metropolitana = dict(votos_regiao_metropolitana)

# %%
# Cálculo da porcentagem de votos que cada candidato ao senado obteve em cada município da Região Metropolitana de Fortaleza:
# Para isso define-se uma função para o cálculo.

def porcentagem_votos(dataframe: pd.DataFrame, dictionary: dict):

  percentual_de_votos = list()

  for index, row in dataframe.iterrows(): # itera-se o dataframe para obter cada linha dele.
    porcentagem = round((row['qt_votos']/dictionary[row['nm_municipio']]) * 100, 2) # os votos são divididos pelo total de votos por município.
    percentual_de_votos.append(porcentagem) # o valor calculado é adicionado a lista.

  return percentual_de_votos

# %%
# A coluna com porcentagem de votos é adicionada ao dataframe:

porcentagens = porcentagem_votos(vencedores_regiao_metropolitana, votos_regiao_metropolitana) # porcentagens armazena as porcentagens de votos.
vencedores_regiao_metropolitana['porcentagem'] = porcentagens # criação da nova coluna no dataframe.

# %%
vencedores_regiao_metropolitana.head()
# Out:
#    nm_municipio                 nm_votavel  qt_votos  porcentagem
# 6       AQUIRAZ  LUIZ INÁCIO LULA DA SILVA     31902        60.38
# 1       AQUIRAZ     JAIR MESSIAS BOLSONARO     15296        28.95
# 0       AQUIRAZ        CIRO FERREIRA GOMES      2605         4.93
# 12      AQUIRAZ                  VOTO NULO      1170         2.21
# 7       AQUIRAZ        SIMONE NASSAR TEBET       761         1.44

# %%
fig = px.bar(
    data_frame= vencedores_regiao_metropolitana, y= 'nm_municipio', x= 'porcentagem', color= 'nm_votavel',
    title= 'Porcentagem dos votos nos candidados à presidência por município da Região Metropolitana de Fortaleza'
)
fig.update_layout(title= dict(x= 0.5), yaxis= dict(autorange= 'reversed'), yaxis_title= 'Municípios', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="82e4adb9-2818-43f1-a5ef-8cac2d9c8dc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82e4adb9-2818-43f1-a5ef-8cac2d9c8dc0")) {                    Plotly.newPlot(                        "82e4adb9-2818-43f1-a5ef-8cac2d9c8dc0",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ IN\u00c1CIO LULA DA SILVA<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[60.38,61.61,56.08,68.05,51.37,51.3,70.95,58.58,60.52,55.27,61.23,57.49,58.15,64.32,58.59,67.95,59.69,69.12,68.13],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=JAIR MESSIAS BOLSONARO<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"textposition":"auto","x":[28.95,26.42,31.08,21.05,37.08,33.91,20.34,29.21,29.03,32.52,28.69,29.65,30.59,25.19,31.43,23.32,29.32,21.5,21.39],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=CIRO FERREIRA GOMES<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"textposition":"auto","x":[4.93,5.28,6.26,5.17,5.95,8.35,4.25,5.87,4.52,6.14,4.76,6.49,5.68,4.67,4.95,3.67,5.28,4.13,5.8],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[2.21,2.74,2.8,2.39,1.84,2.27,1.95,2.63,2.53,2.49,2.26,2.63,2.47,2.49,1.94,2.38,2.31,2.37,2.18],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SIMONE NASSAR TEBET<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"textposition":"auto","x":[1.44,1.46,1.49,0.83,1.53 ...

# %% [markdown]
# > * As porcentagens de votos no candidato eleito **Luiz Inácio Lula da Silva ** variam entre cerca de 51% e 71%.
# > * **Fortaleza e Eusébio** foram os municípios da Região Metropolitana de Fortaleza onde o ex-presidente **Jair Messias Bolsonaro teve melhor desempenho eleitoral.**

# %% [markdown]
# ## 4.6 Comparação dos votos com os indicadores do IBGE

# %%
dados_ibge = pd.read_csv('/content/drive/MyDrive/Datasets/resumo_dados_ibge_ce.csv', encoding= 'latin-1')
dados_ibge.head()
# Out:
#        nome  area_territorio  populacao   idhm  pib_per_capita  \
# 0   ABAIARA          180.833      11965  0.628         9158.04
# 1   ACARAPE          130.002      15140  0.606        10317.47
# 2    ACARAÚ          842.471      63556  0.601        13261.89
# 3  ACOPIARA         2254.279      54687  0.595         9432.25
# 4    AIUABA         2438.563      17584  0.569         8642.90
#
#    area_urbanizada  porcentagem_urbana  densidade_populacional
# 0             3.19                1.76                   66.17
# 1             2.28                1.75                  116.46
# 2            16.33                1.94                   75.44
# 3             5.46                0.24                   24.26
# 4             2.07                0.08                    7.21

# %% [markdown]
# Visto que o candidato eleito Luiz Inácio Lula da Silva saiu como o mais votado em todos os municípios cearenses, não faz sentido comparar o mapa com os candidatos vencedores por município do Ceará. Portanto, as análises serão feitas comparando o mapa com o percentual de votos do candidato vencedor com os indicadores socioeconômicos do IBGE.

# %%
# Os votos no candidato eleito Lula da Silva por município cearense são obtidos:

votos_lula_por_municipio = presidente.query('nm_votavel == "LUIZ INÁCIO LULA DA SILVA"')\
                                     .groupby('nm_municipio')['qt_votos'].sum().reset_index()

votos_lula_por_municipio.head()
# Out:
#   nm_municipio  qt_votos
# 0      ABAIARA      4870
# 1      ACARAPE      5996
# 2       ACARAÚ     24551
# 3     ACOPIARA     23642
# 4       AIUABA      7010

# %%
# Somam-se os votos totais para cada município cearense:

votos_totais_por_municipio = presidente.groupby('nm_municipio')['qt_votos'].sum()
votos_totais_por_municipio = dict(votos_totais_por_municipio) # dicionário com o nº de votos por município, cada nome do município é uma chave.

# %%
# A porcentagem de votos no candidato eleito Lula da Silva por município é, então, calculada:

porcentagens_lula = porcentagem_votos(votos_lula_por_municipio, votos_totais_por_municipio)

# E os valores são inseridos no dataframe com a criação de uma nova coluna:

votos_lula_por_municipio['porcentagem_votos'] = porcentagens_lula
votos_lula_por_municipio.head()
# Out:
#   nm_municipio  qt_votos  porcentagem_votos
# 0      ABAIARA      4870              82.29
# 1      ACARAPE      5996              59.80
# 2       ACARAÚ     24551              66.85
# 3     ACOPIARA     23642              76.33
# 4       AIUABA      7010              80.92

# %%
# É feito o merge dos dados geoespaciais dos municípios com os indicadores do IBGE:

dados_ibge = pd.merge(
    left= ceara_gpd[['name_muni', 'geometry']], right= dados_ibge,
    how= 'left', left_on= 'name_muni', right_on= 'nome'
)
dados_ibge = dados_ibge.drop('nome', axis= 1) # a coluna nome é retirada, pois é redundante.

# É feito o merge dos dados geoespaciais dos municípios com os dados dos votos no candidato eleito Lula da Silva:

votos_lula_por_municipio = pd.merge(
    left= ceara_gpd[['name_muni', 'geometry']], right= votos_lula_por_municipio,
    how= 'left', left_on= 'name_muni', right_on= 'nm_municipio'
)
votos_lula_por_municipio = votos_lula_por_municipio.drop('nm_municipio', axis= 1) # a coluna nm_municipio é retirada, pois é redundante.

# %% [markdown]
# ### 4.6.1 Densidade populacional

# %% [markdown]
# O conjunto de dados na coluna `densidade_populacional` é bastante discrepante. O município de Fortaleza concentra mais de 2,5 milhões de habitantes em território modesto, se comparado a outros municípios cearenses. Portanto, aplica-se transformação logarítimica para homogeneizar e visualizar melhor os dados:

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_lula_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Lula da Silva')
ax2 = dados_ibge.plot(np.log(dados_ibge['densidade_populacional']), cmap= 'Oranges', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Log(Densidade populacional) dos municípios cearenses')
plt.show()

# %% [markdown]
# ### 4.6.2 Indíce de desenvolvimento humano municipal (IDHM)

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_lula_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Lula da Silva')
ax2 = dados_ibge.plot('idhm', cmap= 'BuGn', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Indíce de desenvolvimento humano nos municípios cearenses')
plt.show()

# %% [markdown]
# ### 4.6.3 PIB *per capita*

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_lula_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Lula da Silva')
ax2 = dados_ibge.plot(np.log(dados_ibge['pib_per_capita']), cmap= 'YlGn', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Log(PIB per capita) dos municípios cearenses')
plt.show()

# %% [markdown]
# ### 4.6.4 Área urbanizada

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_lula_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Log(Porcentagem de votos) do candidato eleito Lula da Silva')
ax2 = dados_ibge.plot(np.log(dados_ibge['porcentagem_urbana']), cmap= 'Purples', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Log(Porcentagem urbanizada) dos território nos municípios cearenses')
plt.show()

# %% [markdown]
# ## 4.7 Análise por intervalo de indicadores socioeconômicos

# %% [markdown]
# Há a possibilidade de analisar os votos por grupos, intervalos dos indicadores socioeconômicos do IBGE. Instancia-se um *dataframe* com a quantidade de votos para cada candidato em cada município cearense.

# %%
# Os dados são agrupados por nome do município e candidato e os votos somados. Por último, os indíces são resetados:

votos_candidatos_por_municipio = presidente.groupby(['nm_municipio', 'nm_votavel'])['qt_votos'].sum().reset_index()
votos_candidatos_por_municipio.head()
# Out:
#   nm_municipio                      nm_votavel  qt_votos
# 0      ABAIARA             CIRO FERREIRA GOMES       183
# 1      ABAIARA          JAIR MESSIAS BOLSONARO       594
# 2      ABAIARA      KELMON LUIS DA SILVA SOUZA         4
# 3      ABAIARA  LEONARDO PÉRICLES VIEIRA ROQUE         1
# 4      ABAIARA      LUIZ FELIPE CHAVES D AVILA         1

# %%
# Os dados socioeconômicos do IBGE são juntados ao dataframe dos votos:

votos_candidatos_por_municipio = pd.merge(
    left= votos_candidatos_por_municipio, right= dados_ibge,
    how= 'left', left_on= 'nm_municipio', right_on= 'name_muni'
)

# A coluna nome é retirada, pois os dados são redundantes:

votos_candidatos_por_municipio = votos_candidatos_por_municipio.drop('name_muni', axis= 1)
votos_candidatos_por_municipio.head()
# Out:
#   nm_municipio                      nm_votavel  qt_votos  \
# 0      ABAIARA             CIRO FERREIRA GOMES       183
# 1      ABAIARA          JAIR MESSIAS BOLSONARO       594
# 2      ABAIARA      KELMON LUIS DA SILVA SOUZA         4
# 3      ABAIARA  LEONARDO PÉRICLES VIEIRA ROQUE         1
# 4      ABAIARA      LUIZ FELIPE CHAVES D AVILA         1
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 2  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 3  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 4  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
# 2      11965  0.628         9158.04             3.19                1.76
# 3      11965  0.628         9158.04             3.19                1.76
# 4      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional
# 0                   66.17
# 1                   66.17
# 2                   66.17
# 3                   66.17
# 4                   66.17

# %% [markdown]
# As funções abaixo serão utilizadas para ajustar os dados para análise:

# %%
def intervalos_ibge(dataframe: pd.DataFrame, nome_coluna: str, nova_coluna: str, bins: list, labels: list):
  '''
  A função 'intervalos_ibge' adiciona ao dataframe com os votos dos candidatos por município uma nova coluna. Tal coluna passa a conter um intervalo
  pré-determinado determinado indicador do IBGE relacionado ao município em questão.

  dataframe: dataframe contendo os votos por candidato em cada município.
  nome_coluna: coluna com a informação que será utilizada para gerar o intervalo.
  nova_coluna: nome da nova coluna contendo os intervalos dos indicadores do IBGE.
  bins: lista com os valores que serão usados para formar os intervalos dos indicadores.
  labels: lista com as labels dos intervalos.
  '''

  dataframe[nova_coluna] = pd.cut(
      dataframe[nome_coluna], bins= bins, labels= labels,
      include_lowest= True, right= False # o valor mais baixo é incluso, enquanto o valor maior não é incluso.
  )

  return dataframe # retorna o dataframe, agora contendo a coluna com os intervalos dos indicadores do IBGE.

def dict_votos_totais(dataframe: pd.DataFrame, coluna_indicador: str):
  '''
  A função dict_votos_totais retorna um dicionário com a quantidade de votos gerais para cada intervalo dos indicadores do IBGE.

  dataframe: contendo os votos por candidato em cada município, além da coluna com os intervalos dos indicadores.
  coluna_indicador: nome da coluna contendo os intervalos dos indicadores.
  '''

  valores_totais = dataframe.groupby(coluna_indicador)['qt_votos'].sum()
  valores_totais = dict(valores_totais)

  return valores_totais

def dataframe_com_porcentagens(dataframe: pd.DataFrame, dictionary: dict, coluna_indicador: str):
  '''
  A função dataframe_com_porcentagens retorna um dataframe contendo a porcentagem de votos para cada candidato referente a cada intervalo de indicador.

  dataframe: dataframe com votos dos candidatos por municípios.
  dictionary: dicionário contendo os votos totais de cada intervalo de indicador do IBGE.
  coluna_indicador: coluna com o indicador do IBGE que se deseja calcular os valores de porcentagem.
  '''

  # O dataframe é agrupado pela coluna com os indicadores e nome dos candidatos, os votos são somados e ordenados:

  dataframe_intervalos_ibge = dataframe.groupby([coluna_indicador, 'nm_votavel'])['qt_votos'].sum()\
                                       .reset_index().sort_values([coluna_indicador, 'qt_votos'], ascending= [True, False])

  # A porcentagem para cada candidado em cada intervalo do indicador é calculada:

  porcentagem = list()

  for index, row in dataframe_intervalos_ibge.iterrows():
    valor = round((row['qt_votos']/dictionary[row[coluna_indicador]]) * 100, 2)
    porcentagem.append(valor)

  # E depois uma nova coluna é adicionada ao dataframe que é retornado:

  dataframe_intervalos_ibge['porcentagem_' + coluna_indicador] = porcentagem # o nome da coluna é obtido a partir da concatenação das strings.

  return dataframe_intervalos_ibge

# %% [markdown]
# ### 4.7.1 Intervalos populacionais

# %%
# Intervalos:

bins = [0, 100000, 500000, 3000000]

# Labels para os intervalos populacionais:

labels = ['Menos de 100 mil habitantes', '100 mil e menos de 500 mil habitantes', '500 mil habitantes ou mais']

# %%
# Uma nova coluna com os intervalos populacionais é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'populacao',
    nova_coluna= 'populacao_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio              nm_votavel  qt_votos  \
# 0      ABAIARA     CIRO FERREIRA GOMES       183
# 1      ABAIARA  JAIR MESSIAS BOLSONARO       594
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos
# 0                   66.17  Menos de 100 mil habitantes
# 1                   66.17  Menos de 100 mil habitantes

# %%
# Os votos totais para cada intervalo populacional são mostrados no dicionário:

votos_por_intervalo_populacional = dict_votos_totais(votos_candidatos_por_municipio, 'populacao_intervalos')
votos_por_intervalo_populacional
# Out:
# {'Menos de 100 mil habitantes': 3146267,
#  '100 mil e menos de 500 mil habitantes': 918998,
#  '500 mil habitantes ou mais': 1563345}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_populacionais = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_populacional, 'populacao_intervalos'
)
votos_intervalos_populacionais.head()
# Out:
#            populacao_intervalos                 nm_votavel  qt_votos  \
# 6   Menos de 100 mil habitantes  LUIZ INÁCIO LULA DA SILVA   2197649
# 1   Menos de 100 mil habitantes     JAIR MESSIAS BOLSONARO    623212
# 0   Menos de 100 mil habitantes        CIRO FERREIRA GOMES    172469
# 12  Menos de 100 mil habitantes                  VOTO NULO     70865
# 11  Menos de 100 mil habitantes                VOTO BRANCO     39662
#
#     porcentagem_populacao_intervalos
# 6                              69.85
# 1                              19.81
# 0                               5.48
# 12                              2.25
# 11                              1.26

# %%
fig = px.bar(
    data_frame= votos_intervalos_populacionais,
    y= 'populacao_intervalos',
    x= 'porcentagem_populacao_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo populacional dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9b7ad7a2-579e-4470-8f8e-492d4b198462" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b7ad7a2-579e-4470-8f8e-492d4b198462")) {                    Plotly.newPlot(                        "9b7ad7a2-579e-4470-8f8e-492d4b198462",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ IN\u00c1CIO LULA DA SILVA<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[69.85,62.97,51.3],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=JAIR MESSIAS BOLSONARO<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"textposition":"auto","x":[19.81,24.42,33.91],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=CIRO FERREIRA GOMES<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"textposition":"auto","x":[5.48,7.2,8.35],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[2.25,2.26,2.27],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[1.26,1.35,1.29],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SIMONE NASSAR TEBET<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"textposition":"auto","x":[0.81,1.12,1.95],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SORAYA VIEIRA THRONICKE<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"SORAYA VIEIRA THRONICKE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name ...

# %% [markdown]
# > * O percentual de votos dos candidatos **Jair Bolsonaro e Ciro Gomes cresce nos grupos com maior população.** Com **Jair Bolsonaro** atingindo quase **34% no grupo dos municípios com mais de 500 mil habitantes.**
# > * Já com o candidato eleito **Luiz Inácio Lula da Silva** o comportamento visualizado é o contrário, apesar de ter a maioria dos votos em todos os grupos populacionais, **nos municípios com mais de 500 mil habitantes sua porcentagem de foi menor que nos outros grupos, apesar de ter mais da metade dos votos.**

# %% [markdown]
# ### 4.7.2 Intervalos de indíce de desenvolvimento humano (IDHM)

# %%
# Intervalos:

bins = [0, 0.55, 0.7, 0.8]

# Labels para os intervalos de IDH municipal:

labels = ['IDH baixo', 'IDH médio', 'IDH alto']

# %%
# Uma nova coluna com os intervalos de IDHM é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'idhm',
    nova_coluna= 'idhm_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio              nm_votavel  qt_votos  \
# 0      ABAIARA     CIRO FERREIRA GOMES       183
# 1      ABAIARA  JAIR MESSIAS BOLSONARO       594
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos idhm_intervalos
# 0                   66.17  Menos de 100 mil habitantes       IDH médio
# 1                   66.17  Menos de 100 mil habitantes       IDH médio

# %%
# Os votos totais para cada intervalo de IDHM são mostrados no dicionário:

votos_por_intervalo_idhm = dict_votos_totais(votos_candidatos_por_municipio, 'idhm_intervalos')
votos_por_intervalo_idhm
# Out:
# {'IDH baixo': 11019, 'IDH médio': 3805920, 'IDH alto': 1811671}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_idhm = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_idhm, 'idhm_intervalos'
)
votos_intervalos_idhm.head()
# Out:
#    idhm_intervalos                 nm_votavel  qt_votos  \
# 6        IDH baixo  LUIZ INÁCIO LULA DA SILVA      8462
# 1        IDH baixo     JAIR MESSIAS BOLSONARO      1388
# 0        IDH baixo        CIRO FERREIRA GOMES       802
# 12       IDH baixo                  VOTO NULO       207
# 11       IDH baixo                VOTO BRANCO        93
#
#     porcentagem_idhm_intervalos
# 6                         76.79
# 1                         12.60
# 0                          7.28
# 12                         1.88
# 11                         0.84

# %%
fig = px.bar(
    data_frame= votos_intervalos_idhm,
    y= 'idhm_intervalos',
    x= 'porcentagem_idhm_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo de IDH municipal dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4dab1428-5a0b-411d-9b9b-82be326144f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dab1428-5a0b-411d-9b9b-82be326144f2")) {                    Plotly.newPlot(                        "4dab1428-5a0b-411d-9b9b-82be326144f2",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ IN\u00c1CIO LULA DA SILVA<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[76.79,68.74,52.64],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=JAIR MESSIAS BOLSONARO<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"textposition":"auto","x":[12.6,20.77,32.34],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=CIRO FERREIRA GOMES<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"textposition":"auto","x":[7.28,5.51,8.76],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[1.88,2.27,2.24],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[0.84,1.26,1.34],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SIMONE NASSAR TEBET<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"textposition":"auto","x":[0.36,0.88,1.8],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SORAYA VIEIRA THRONICKE<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"SORAYA VIEIRA THRONICKE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SORAYA VIEIRA THRONICKE","offsetgroup":"SORAYA VIEIRA THRONICKE","orientation":"h","showlegend":true,"textposition":"auto","x":[0.14,0.41,0.5],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ FELIPE CHAVES D AVILA<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"LUIZ FELIPE CHAVES D AV ...

# %% [markdown]
# > * O intervalo IDH baixo é referente unicamente ao município de Salitre, o que pode ser visto abaixo:

# %%
votos_candidatos_por_municipio.query('idhm_intervalos == "IDH baixo"')['nm_municipio'].unique()
# Out:
# array(['SALITRE'], dtype=object)

# %% [markdown]
# > * E nesse município, em específico, o candidato** Jair Bolsonaro teve um desempenho eleitoral baixo, acompanhado de grande percentual de votos do candidato eleito Lula da Silva.**
# > * Tanto **Jair Bolsonaro**, quanto **Ciro Gomes** tiverem **melhor desempenho no grupo com os municípios de IDH alto.** O **menor desempenho** de **Lula da Silva também ocorreu nesse grupo**, mas ainda com a maioria dos votos (52,64%).

# %% [markdown]
# ### 4.7.3 Intervalos de PIB *per capita*

# %%
# Intervalos:

bins = [0, 10000, 20000, 90000]

# Labels para os intervalos de PIB per capita:

labels = ['Menos de R$ 10000', 'Entre R$ 10000 - 19999,99', 'R$ 20000 ou mais']

# %%
# Uma nova coluna com os intervalos de PIB per capita é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'pib_per_capita',
    nova_coluna= 'pib_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio              nm_votavel  qt_votos  \
# 0      ABAIARA     CIRO FERREIRA GOMES       183
# 1      ABAIARA  JAIR MESSIAS BOLSONARO       594
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos idhm_intervalos  \
# 0                   66.17  Menos de 100 mil habitantes       IDH médio
# 1                   66.17  Menos de 100 mil habitantes       IDH médio
#
#       pib_intervalos
# 0  Menos de R$ 10000
# 1  Menos de R$ 10000

# %%
# Os votos totais para cada intervalo de PIB per capita são mostrados no dicionário:

votos_por_intervalo_pib = dict_votos_totais(votos_candidatos_por_municipio, 'pib_intervalos')
votos_por_intervalo_pib
# Out:
# {'Menos de R$ 10000': 1131915,
#  'Entre R$ 10000 - 19999,99': 2323021,
#  'R$ 20000 ou mais': 2173674}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_pib = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_pib, 'pib_intervalos'
)
votos_intervalos_pib.head()
# Out:
#        pib_intervalos                 nm_votavel  qt_votos  \
# 6   Menos de R$ 10000  LUIZ INÁCIO LULA DA SILVA    838927
# 1   Menos de R$ 10000     JAIR MESSIAS BOLSONARO    180904
# 0   Menos de R$ 10000        CIRO FERREIRA GOMES     59565
# 12  Menos de R$ 10000                  VOTO NULO     25418
# 11  Menos de R$ 10000                VOTO BRANCO     13097
#
#     porcentagem_pib_intervalos
# 6                        74.12
# 1                        15.98
# 0                         5.26
# 12                        2.25
# 11                        1.16

# %%
fig = px.bar(
    data_frame= votos_intervalos_pib,
    y= 'pib_intervalos',
    x= 'porcentagem_pib_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo de PIB per capita dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="73b16684-a200-4afe-944f-eae270daf0e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73b16684-a200-4afe-944f-eae270daf0e2")) {                    Plotly.newPlot(                        "73b16684-a200-4afe-944f-eae270daf0e2",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ IN\u00c1CIO LULA DA SILVA<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[74.12,68.19,53.15],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=JAIR MESSIAS BOLSONARO<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"textposition":"auto","x":[15.98,21.31,32.29],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=CIRO FERREIRA GOMES<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"textposition":"auto","x":[5.26,5.56,8.31],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[2.25,2.22,2.31],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[1.16,1.25,1.38],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SIMONE NASSAR TEBET<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"textposition":"auto","x":[0.72,0.91,1.7],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SORAYA VIEIRA THRONICKE<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"SORAYA VIEIRA THRONICKE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SORAYA VIEIRA THRONICKE","offsetgroup":"SORAYA VIEIRA THRONICKE","orientation":"h","showlegend":true,"textposition":"auto","x":[0.38,0.39,0.51],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup" ...

# %% [markdown]
# > * O percentual de votos dos candidatos **Jair Bolsonaro e Ciro Gomes cresce nos grupos de municípios com maior PIB *per capita*.**
# * **A tendência inversa acontece com Lula da Silva**, apesar de ter em todos os grupos mais da metade dos votos.

# %% [markdown]
# ### 4.7.4 Intervalos de território urbanizado

# %%
# Intervalos:

bins= [0, 10, 40, 90]

# Labels para os intervalos de território urbanizado:

labels= ['Menos de 10%', 'Entre 10 - 39,99%', '40% ou mais']

# %%
# Uma nova coluna com os intervalos de território urbanizado é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'porcentagem_urbana',
    nova_coluna= 'urbana_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio              nm_votavel  qt_votos  \
# 0      ABAIARA     CIRO FERREIRA GOMES       183
# 1      ABAIARA  JAIR MESSIAS BOLSONARO       594
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos idhm_intervalos  \
# 0                   66.17  Menos de 100 mil habitantes       IDH médio
# 1                   66.17  Menos de 100 mil habitantes       IDH médio
#
#       pib_intervalos urbana_intervalos
# 0  Menos de R$ 10000      Menos de 10%
# 1  Menos de R$ 10000      Menos de 10%

# %%
# Os votos totais para cada intervalo de território urbanizado são mostrados no dicionário:

votos_por_intervalo_urbana = dict_votos_totais(votos_candidatos_por_municipio, 'urbana_intervalos')
votos_por_intervalo_urbana
# Out:
# {'Menos de 10%': 3609410, 'Entre 10 - 39,99%': 307098, '40% ou mais': 1712102}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_urbana = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_urbana, 'urbana_intervalos'
)
votos_intervalos_urbana.head()
# Out:
#    urbana_intervalos                 nm_votavel  qt_votos  \
# 6       Menos de 10%  LUIZ INÁCIO LULA DA SILVA   2497819
# 1       Menos de 10%     JAIR MESSIAS BOLSONARO    721929
# 0       Menos de 10%        CIRO FERREIRA GOMES    212681
# 12      Menos de 10%                  VOTO NULO     81328
# 11      Menos de 10%                VOTO BRANCO     45982
#
#     porcentagem_urbana_intervalos
# 6                           69.20
# 1                           20.00
# 0                            5.89
# 12                           2.25
# 11                           1.27

# %%
fig = px.bar(
    data_frame= votos_intervalos_urbana,
    y= 'urbana_intervalos',
    x= 'porcentagem_urbana_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo de território urbanizado dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8a8c4eef-3063-40c1-8c39-d47b625e2126" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a8c4eef-3063-40c1-8c39-d47b625e2126")) {                    Plotly.newPlot(                        "8a8c4eef-3063-40c1-8c39-d47b625e2126",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ IN\u00c1CIO LULA DA SILVA<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LUIZ IN\u00c1CIO LULA DA SILVA","offsetgroup":"LUIZ IN\u00c1CIO LULA DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[69.2,63.92,51.65],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=JAIR MESSIAS BOLSONARO<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"JAIR MESSIAS BOLSONARO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"JAIR MESSIAS BOLSONARO","offsetgroup":"JAIR MESSIAS BOLSONARO","orientation":"h","showlegend":true,"textposition":"auto","x":[20.0,25.19,33.79],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=CIRO FERREIRA GOMES<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"CIRO FERREIRA GOMES","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CIRO FERREIRA GOMES","offsetgroup":"CIRO FERREIRA GOMES","orientation":"h","showlegend":true,"textposition":"auto","x":[5.89,5.48,8.16],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[2.25,2.14,2.29],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[1.27,1.3,1.3],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SIMONE NASSAR TEBET<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"SIMONE NASSAR TEBET","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"SIMONE NASSAR TEBET","offsetgroup":"SIMONE NASSAR TEBET","orientation":"h","showlegend":true,"textposition":"auto","x":[0.82,1.33,1.9],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=SORAYA VIEIRA THRONICKE<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"SORAYA VIEIRA THRONICKE","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SORAYA VIEIRA THRONICKE","offsetgroup":"SORAYA VIEIRA THRONICKE","orientation":"h","showlegend":true,"textposition":"auto","x":[0.4,0.41,0.52],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=LUIZ FELIPE CHAVES D AVILA<br>porcentagem_urbana_inte ...

# %% [markdown]
# > * O percentual de votos de **Ciro Gomes** **pouco se altera entre os dois primeiros grupos** e é **mais significativo** nos municípios **mais urbanizados.**
# * O percentual de votos de **Jair Bolsonaro** **cresce** nos grupos de cidades **mais urbanizadas.**
# * E a tendência é **inversa** para **Lula da Silv**a, mesmo assim ele mantém **mais de metade dos votos** no grupo mais urbanizado.
