# %% [markdown]
# <a href="https://colab.research.google.com/github/DamodaraBarbosa/eleicoes_ceara_2022/blob/main/07_senador_analise_eleicoes_ceara_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas geobr descartes
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: geobr in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: descartes in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descartes) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.0->geopandas) (1.22.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=2.2.0->geopandas) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (8.1.4)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona->geopandas) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (3.1.0)

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from geobr import read_municipality
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
# Para ignorar qualquer aviso:

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Carregamento dos dados no *dataframe*

# %%
votacao_ce = pd.read_csv(
    '/content/drive/MyDrive/Datasets/votacao_secao_2022_CE_tratado.csv',
    encoding= 'latin-1', sep= ','
)

# %%
votacao_ce.head()
# Out:
#   nm_municipio  nr_zona  nr_secao          ds_cargo  nr_votavel  \
# 0    FORTALEZA       94         6  DEPUTADO FEDERAL        4444
# 1       RUSSAS        9       266  DEPUTADO FEDERAL        4444
# 2    PARAIPABA      109       119  DEPUTADO FEDERAL        4444
# 3    ITAPIPOCA       17        25  DEPUTADO FEDERAL        4444
# 4     SABOEIRO       43       228  DEPUTADO FEDERAL        4444
#
#                       nm_votavel  qt_votos
# 0  HEITOR RODRIGO PEREIRA FREIRE         4
# 1  HEITOR RODRIGO PEREIRA FREIRE        13
# 2  HEITOR RODRIGO PEREIRA FREIRE         3
# 3  HEITOR RODRIGO PEREIRA FREIRE         2
# 4  HEITOR RODRIGO PEREIRA FREIRE         4

# %% [markdown]
# # 2. Informações do *dataframe*

# %% [markdown]
# A base de dados utilizada nesta análise é a mesma feita em outras análises. Portanto, algumas informações do *dataframe* como as suas dimensões, os tipos de dado de cada coluna e a presença de dados duplicados e faltantes podem ser vistas no *notebook*: https://github.com/DamodaraBarbosa/eleicoes_ceara_2022/blob/main/05_data_analysis_eleicoes_ceara_2022.ipynb

# %% [markdown]
# # 3. Tratamento dos dados

# %% [markdown]
# Apesar de serem valores numéricos, os dados das colunas `nr_zona` e `nr_secao` são categóricos já que representam zonas e seções eleitorais.

# %%
# Conversão dos dados das colunas para tipo string:

votacao_ce['nr_zona'] = votacao_ce['nr_zona'].astype(str)
votacao_ce['nr_secao'] = votacao_ce['nr_secao'].astype(str)

# %%
votacao_ce.dtypes
# Out:
# nm_municipio    object
# nr_zona         object
# nr_secao        object
# ds_cargo        object
# nr_votavel       int64
# nm_votavel      object
# qt_votos         int64
# dtype: object

# %% [markdown]
# # 4. Análise eleitoral para cargo de senador do estado do Ceará

# %% [markdown]
# ## 4.1 Candidatos

# %%
# Buscam-se apenas os dados referentes ao cargo de senador:

senador = votacao_ce.query('ds_cargo == "SENADOR"')
senador.head()
# Out:
#           nm_municipio nr_zona nr_secao ds_cargo  nr_votavel   nm_votavel  \
# 575  LIMOEIRO DO NORTE      29      109  SENADOR          95  VOTO BRANCO
# 576            CANINDÉ      33      488  SENADOR          95  VOTO BRANCO
# 577   SÃO LUÍS DO CURU      23      323  SENADOR          95  VOTO BRANCO
# 578           BARREIRA      52      142  SENADOR          95  VOTO BRANCO
# 579              CRATO      27      304  SENADOR          95  VOTO BRANCO
#
#      qt_votos
# 575         7
# 576        14
# 577        16
# 578        12
# 579        10

# %% [markdown]
# Ao buscar os dados únicos na coluna `nm_votavel` observa-se que:

# %%
senador['nm_votavel'].unique()
# Out:
# array(['VOTO BRANCO', 'VOTO NULO', 'CAMILO SOBREIRA DE SANTANA',
#        'FRANCISCO CARLOS ALVES DA SILVA', 'ERIKA GONÇALVES AMORIM',
#        'KAMILA CARDOSO DE SOUZA RIBEIRO'], dtype=object)

# %% [markdown]
# > Excetuando-se votos em branco e nulos, os candidados são: Camilo Santana, Fco Carlos Silva, Erika Gonçalves e Kamila Cardoso.

# %% [markdown]
# ## 4.2 Votos por candidato

# %%
# Os votos por senador são determinados e o dataframe é ordenado decrescentemente:

votos_por_senador = senador.groupby('nm_votavel')['qt_votos'].sum().to_frame().sort_values('qt_votos', ascending= False)

# %%
fig = px.bar(
    data_frame= votos_por_senador,
    y= votos_por_senador.index,
    x= 'qt_votos', text= 'qt_votos',
    color= votos_por_senador.index,
    title= 'Votos nos candidatos ao cargo de senador do Ceará'
)
fig.update_xaxes(range= [0, 3.7e6])
fig.update_layout(title= dict(x= 0.5), yaxis_title= 'Candidatos', xaxis_title= 'Quantidade de votos', showlegend= False)
fig.update_traces(textfont_size= 12, textposition= 'outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b47d4102-8961-444d-81b0-34f1501ff4e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b47d4102-8961-444d-81b0-34f1501ff4e0")) {                    Plotly.newPlot(                        "b47d4102-8961-444d-81b0-34f1501ff4e0",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"text":[3389513.0],"textposition":"outside","x":[3389513],"xaxis":"x","y":["CAMILO SOBREIRA DE SANTANA"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"text":[1273272.0],"textposition":"outside","x":[1273272],"xaxis":"x","y":["KAMILA CARDOSO DE SOUZA RIBEIRO"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"text":[451233.0],"textposition":"outside","x":[451233],"xaxis":"x","y":["VOTO NULO"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"text":[313270.0],"textposition":"outside","x":[313270],"xaxis":"x","y":["VOTO BRANCO"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"text":[193243.0],"textposition":"outside","x":[193243],"xaxis":"x","y":["ERIKA GON\u00c7ALVES AMORIM"],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"nm_votavel=%{y}<br>qt_votos=%{text}<extra></extra>","legendgroup":"FRANCISCO CARLOS ALVES DA SILVA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"FRANCISCO CARLOS ALVES DA SILVA","offsetgroup":"FRANCISCO CARLOS ALVES DA SILVA","orientation":"h","showlegend":true,"text":[2919.0],"textposition":"outside","x":[2919],"xaxis":"x","y":["FRANCISCO CARLOS ALVES DA SILVA"],"yaxis":"y","type":"bar","textfont":{"size":12}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed ...

# %% [markdown]
# Os candidatos mais votados foram:
#
# > * **1º:** Camilo Sobreira de Santana (Candidato eleito) 🥇
# > * **2º:** Kamila Cardoso de Souza Ribeiro 🥈
# >
# > Os demais candidatos receberam menos votos que **VOTO BRANCO e NULO.**

# %% [markdown]
# ## 4.3 Porcentagem dos votos totais e válidos ao senado

# %%
# Excetuam-se os votos brancos e nulos:

votos_validos = senador.query('nm_votavel != ["VOTO NULO", "VOTO BRANCO"]')

# Calcula-se apenas os votos válidos:

total_votos_validos = votos_validos['qt_votos'].sum()
print(f'Votos válidos: {total_votos_validos}')

# Votos totais incluindo brancos e nulos:

total_votos = senador['qt_votos'].sum()
print(f'Votos totais: {total_votos}')
# Out:
# Votos válidos: 4858947
# Votos totais: 5623450

# %%
votos_validos['nm_votavel'].unique()
# Out:
# array(['CAMILO SOBREIRA DE SANTANA', 'FRANCISCO CARLOS ALVES DA SILVA',
#        'ERIKA GONÇALVES AMORIM', 'KAMILA CARDOSO DE SOUZA RIBEIRO'],
#       dtype=object)

# %% [markdown]
# > **VOTO BRANCO e VOTO NULO** foram removidos de `votos_validos`.

# %% [markdown]
# Um *dataframe* contendo as informações sobre porcentagens dos votos é instanciado:

# %%
# Instancia-se um dataframe contendo a porcentagem de votos totais e votos válidos por candidato ao senado:

porcentagem_votos_senador = pd.DataFrame(
    {'Votos totais': round((senador.groupby('nm_votavel')['qt_votos'].sum()/total_votos) * 100, 2), # cálculo da porcentagem de votos totais.
     'Votos válidos': round((votos_validos.groupby('nm_votavel')['qt_votos'].sum()/total_votos_validos) * 100, 2)} # cálculo da porcentagem de votos válidos.
).sort_values(['Votos totais', 'Votos válidos'], ascending= [False, False]) # os dados são ordenados em ordem decrescente.

# Utiliza-se o método transpose para inverter index em colunas e vice-versa:

porcentagem_votos_senador = porcentagem_votos_senador.transpose()

# %%
fig = px.bar(
    data_frame= porcentagem_votos_senador,
    y= porcentagem_votos_senador.index,
    x= porcentagem_votos_senador.columns,
    title= 'Porcentagem dos votos totais e válidos ao cargo de senador do Ceará'
)
fig.update_layout(
    yaxis= dict(autorange= 'reversed'), xaxis_title= 'Porcentagem dos votos',
    yaxis_title= '', legend_title= 'Candidatos', title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="210377f1-116b-44a6-a3c6-14f2c92aa44e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("210377f1-116b-44a6-a3c6-14f2c92aa44e")) {                    Plotly.newPlot(                        "210377f1-116b-44a6-a3c6-14f2c92aa44e",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=CAMILO SOBREIRA DE SANTANA<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"textposition":"auto","x":[60.27,69.76],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=KAMILA CARDOSO DE SOUZA RIBEIRO<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"textposition":"auto","x":[22.64,26.2],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[8.02,null],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[5.57,null],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=ERIKA GON\u00c7ALVES AMORIM<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"textposition":"auto","x":[3.44,3.98],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=FRANCISCO CARLOS ALVES DA SILVA<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"FRANCISCO CARLOS ALVES DA SILVA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"FRANCISCO CARLOS ALVES DA SILVA","offsetgroup":"FRANCISCO CARLOS ALVES DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[0.05,0.06],"xaxis":"x","y":["Votos totais","Votos v\u00e1lidos"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %% [markdown]
# > * **Camilo Sobreira de Santana** 🥇: 60,27% dos votos totais e 69,76% dos votos válidos.
# > * **Kamila Cardoso de Souza Ribeiro** 🥈: 22,64% dos votos totais e 26,20% dos votos válidos.

# %% [markdown]
# ## 4.4 Candidato vencedor por município cearense

# %%
# Os votos nos cadidatos ao senado são determinados:

votos_candidatos_por_municipio = senador.groupby(['nm_municipio', 'nm_votavel'])['qt_votos'].sum().reset_index()

# Os dados são ordenados em ordem alfabética para os municípios e em ordem decrescente para os votos:

votos_candidatos_por_municipio = votos_candidatos_por_municipio.sort_values(['nm_municipio', 'qt_votos'], ascending= [True, False])

# Seleciona-se apenas o candidato que obteve mais votos em cada município:

vencedores_por_municipio = votos_candidatos_por_municipio.groupby('nm_municipio').head(1)
vencedores_por_municipio.head() # para visualizar o dataframe.
# Out:
#    nm_municipio                  nm_votavel  qt_votos
# 0       ABAIARA  CAMILO SOBREIRA DE SANTANA      4420
# 6       ACARAPE  CAMILO SOBREIRA DE SANTANA      5489
# 11       ACARAÚ  CAMILO SOBREIRA DE SANTANA     22540
# 17     ACOPIARA  CAMILO SOBREIRA DE SANTANA     19132
# 23       AIUABA  CAMILO SOBREIRA DE SANTANA      6970

# %%
# Dataframe com dados geoespaciais dos municípios cearenses:

ceara_gpd = read_municipality(code_muni= 23, year= 2020)

# Um pequeno tratamento é feito para que os nomes dos municípios estejam em caixa alta:

ceara_gpd['name_muni'] = ceara_gpd['name_muni'].str.upper()

ceara_gpd.head() # visualização do dataframe.
# Out:
#    code_muni name_muni  code_state abbrev_state name_state  code_region  \
# 0  2300101.0   ABAIARA        23.0           CE      Ceará          2.0
# 1  2300150.0   ACARAPE        23.0           CE      Ceará          2.0
# 2  2300200.0    ACARAÚ        23.0           CE      Ceará          2.0
# 3  2300309.0  ACOPIARA        23.0           CE      Ceará          2.0
# 4  2300408.0    AIUABA        23.0           CE      Ceará          2.0
#
#   name_region                                           geometry
# 0    Nordeste  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...
# 1    Nordeste  MULTIPOLYGON (((-38.65304 -4.15796, -38.65108 ...
# 2    Nordeste  MULTIPOLYGON (((-40.30984 -2.80769, -40.26882 ...
# 3    Nordeste  MULTIPOLYGON (((-39.15631 -5.95731, -39.15267 ...
# 4    Nordeste  MULTIPOLYGON (((-40.11801 -6.34845, -40.11298 ...

# %%
vencedores_por_municipio_gpd = pd.merge(
    left= ceara_gpd[['name_muni', 'geometry']], right= vencedores_por_municipio,
    how= 'left', left_on= 'name_muni', right_on= 'nm_municipio'
)
vencedores_por_municipio_gpd = vencedores_por_municipio_gpd.drop('name_muni', axis= 1) # a coluna é eliminada visto que possui dados redundantes.

# %%
vencedores_por_municipio_gpd.head(2)
# Out:
#                                             geometry nm_municipio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...      ABAIARA
# 1  MULTIPOLYGON (((-38.65304 -4.15796, -38.65108 ...      ACARAPE
#
#                    nm_votavel  qt_votos
# 0  CAMILO SOBREIRA DE SANTANA      4420
# 1  CAMILO SOBREIRA DE SANTANA      5489

# %%
ax = vencedores_por_municipio_gpd.plot(
    'nm_votavel', cmap= 'autumn', legend= True,
    legend_kwds= {'loc': 'upper right'},
    figsize= (12, 10)
)
ax.set_title('Candidato vencedor por município cearense')
plt.show()

# %% [markdown]
# > * O candidato eleito **Camilo Santana** obteve **mais votos** em **todos os municípios cearenses.**

# %% [markdown]
# ## 4.5 Votos para senador nos municípios da Região Metropolitana de Fortaleza

# %% [markdown]
# A Região Metropolitana de Fortaleza é constituída de 19 municípios sendo eles:
#
# > * Aquiraz, Cascavel, Caucaia, Chorozinho, Eusébio, Fortaleza, Guaiúba, Horizonte, Itaitinga, Maracanaú, Maranguape, Pacajus, Pacatuba, Pindoretama, São Gonçalo do Amarante, São Luís do Curu, Paraipaba, Paracuru e Trairi.
#
# Fonte: https://pt.wikipedia.org/wiki/Regi%C3%A3o_Metropolitana_de_Fortaleza

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Municípios da Região Metropolitana de Fortaleza:

regiao_metropolitana = [
    'AQUIRAZ', 'CASCAVEL', 'CAUCAIA', 'CHOROZINHO', 'EUSÉBIO',
    'FORTALEZA', 'GUAIÚBA', 'HORIZONTE', 'ITAITINGA', 'MARACANAÚ',
    'MARANGUAPE', 'PACAJUS', 'PACATUBA', 'PINDORETAMA',
    'SÃO GONÇALO DO AMARANTE', 'SÃO LUÍS DO CURU',
    'PARAIPABA', 'PARACURU', 'TRAIRI'
]

# %% [markdown]
# ### 4.5.1 Porcentagem dos votos para o cargo de senador por município da Região Metropolitana de Fortaleza

# %%
# Buscam-se no conjunto de dados ao cargo de senador apenas os municípios da Região Metropolitana de Fortaleza:

senador_regiao_metropolitana = senador.query('nm_municipio in @regiao_metropolitana')

# Agrupam-se os dados por município e candidato para determinar os votos:

vencedores_regiao_metropolitana = senador_regiao_metropolitana.groupby(['nm_municipio', 'nm_votavel'])['qt_votos'].sum().reset_index()

# Os dados são ordenados em ordem alfabética e em ordem decrescente do número de votos:

vencedores_regiao_metropolitana = vencedores_regiao_metropolitana.sort_values(['nm_municipio', 'qt_votos'], ascending= [True, False])

vencedores_regiao_metropolitana.head()
# Out:
#   nm_municipio                       nm_votavel  qt_votos
# 0      AQUIRAZ       CAMILO SOBREIRA DE SANTANA     29895
# 3      AQUIRAZ  KAMILA CARDOSO DE SOUZA RIBEIRO     15239
# 5      AQUIRAZ                        VOTO NULO      4330
# 4      AQUIRAZ                      VOTO BRANCO      2900
# 1      AQUIRAZ           ERIKA GONÇALVES AMORIM       437

# %%
# Instancia-se um dicionário contendo o nº de votos totais ao cargo de senador por município da Região Metropolitana de Fortaleza:

votos_regiao_metropolitana = senador.groupby('nm_municipio')['qt_votos'].sum()
votos_regiao_metropolitana = dict(votos_regiao_metropolitana)

# %%
# Cálculo da porcentagem de votos que cada candidato ao senado obteve em cada município da Região Metropolitana de Fortaleza:
# Para isso define-se uma função para o cálculo.

def porcentagem_votos(dataframe: pd.DataFrame, dictionary: dict):

  percentual_de_votos = list()

  for index, row in dataframe.iterrows(): # itera-se o dataframe para obter cada linha dele.
    porcentagem = round((row['qt_votos']/dictionary[row['nm_municipio']]) * 100, 2) # os votos são divididos pelo total de votos por município.
    percentual_de_votos.append(porcentagem) # o valor calculado é adicionado a lista.

  return percentual_de_votos

# %%
# A coluna com porcentagem de votos é adicionada ao dataframe:

porcentagens = porcentagem_votos(vencedores_regiao_metropolitana, votos_regiao_metropolitana) # porcentagens armazena as porcentagens de votos.
vencedores_regiao_metropolitana['porcentagem'] = porcentagens # criação da nova coluna no dataframe.

# %%
fig = px.bar(
    data_frame= vencedores_regiao_metropolitana, y= 'nm_municipio', x= 'porcentagem', color= 'nm_votavel',
    title= 'Porcentagem dos votos nos candidados ao senado por município da Região Metropolitana de Fortaleza'
)
fig.update_layout(title= dict(x= 0.5), yaxis= dict(autorange= 'reversed'), yaxis_title= 'Municípios', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d9c98518-7e05-4c5d-92b4-67187c55a3f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9c98518-7e05-4c5d-92b4-67187c55a3f2")) {                    Plotly.newPlot(                        "d9c98518-7e05-4c5d-92b4-67187c55a3f2",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=CAMILO SOBREIRA DE SANTANA<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"textposition":"auto","x":[56.59,56.33,47.92,63.56,47.03,49.26,70.48,52.35,55.54,50.13,59.96,51.9,56.57,61.31,56.79,63.59,47.93,64.36,66.87],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=KAMILA CARDOSO DE SOUZA RIBEIRO<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"textposition":"auto","x":[28.85,25.74,26.66,17.86,38.6,33.55,17.43,29.58,30.11,33.04,26.59,29.98,29.06,23.59,28.02,22.18,33.45,19.1,17.65],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[8.2,9.8,9.33,7.71,7.08,8.12,6.7,8.88,7.79,8.72,6.97,9.36,7.69,8.5,7.7,8.65,8.6,7.85,8.25],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[5.49,7.31,6.36,5.48,5.91,6.06,3.9,7.44,5.57,6.9,5.09,6.86,5.63,5.62,5.1,4.74,6.24,6.05,5.07],"xaxis":"x","y":["AQUIRAZ","CASCAVEL","CAUCAIA","CHOROZINHO","EUS\u00c9BIO","FORTALEZA","GUAI\u00daBA","HORIZONTE","ITAITINGA","MARACANA\u00da","MARANGUAPE","PACAJUS","PACATUBA","PARACURU","PARAIPABA","PINDORETAMA","S\u00c3O GON\u00c7ALO DO AMARANTE","S\u00c3O LU\u00cdS DO CURU","TRAIRI"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=ERIKA GON\u00c7ALVES AMORIM<br>porcentagem=%{x}<br>nm_municipio=%{y}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"textposition":"auto","x":[0.83,0.78,9. ...

# %% [markdown]
# > * O candidato eleito **Camilo Santana** teve a **maioria dos votos em todos os municípios da Região Metropolitana de Fortaleza**, como visto anteriormente. Destaca-se o seu desempenho em **Guaiúba** onde obteve mais de **70% dos votos.**
# > * A candidata **Kamila Cardoso** foi a **segunda mais votada.** Obteve melhor desempenho nos municípios de **Fortaleza, Eusébio e São Gonçalo do Amarante.**

# %% [markdown]
# ## 4.6 Comparação dos votos com os indicadores do IBGE

# %%
dados_ibge = pd.read_csv('/content/drive/MyDrive/Datasets/resumo_dados_ibge_ce.csv', encoding= 'latin-1')

# %%
dados_ibge.head()
# Out:
#        nome  area_territorio  populacao   idhm  pib_per_capita  \
# 0   ABAIARA          180.833      11965  0.628         9158.04
# 1   ACARAPE          130.002      15140  0.606        10317.47
# 2    ACARAÚ          842.471      63556  0.601        13261.89
# 3  ACOPIARA         2254.279      54687  0.595         9432.25
# 4    AIUABA         2438.563      17584  0.569         8642.90
#
#    area_urbanizada  porcentagem_urbana  densidade_populacional
# 0             3.19                1.76                   66.17
# 1             2.28                1.75                  116.46
# 2            16.33                1.94                   75.44
# 3             5.46                0.24                   24.26
# 4             2.07                0.08                    7.21

# %% [markdown]
# > Visto que o candidato eleito Camilo Santana saiu como o mais votado em todos os municípios cearenses, não faz sentido comparar o mapa com os candidatos vencedores por município do Ceará. Portanto, as análises serão feitas comparando o mapa com o percentual de votos do candidato com os indicadores socioeconômicos do IBGE.

# %%
# Os votos no candidato eleito Camilo Santana por município cearense são obtidos:

votos_camilo_por_municipio = senador.query('nm_votavel == "CAMILO SOBREIRA DE SANTANA"')\
                                    .groupby('nm_municipio')['qt_votos'].sum().reset_index()

votos_camilo_por_municipio.head()
# Out:
#   nm_municipio  qt_votos
# 0      ABAIARA      4420
# 1      ACARAPE      5489
# 2       ACARAÚ     22540
# 3     ACOPIARA     19132
# 4       AIUABA      6970

# %%
# Somam-se os votos totais para cada município cearense:

votos_totais_por_municipio = senador.groupby('nm_municipio')['qt_votos'].sum()
votos_totais_por_municipio = dict(votos_totais_por_municipio) # dicionário com o nº de votos por município, cada nome do município é uma chave.

# %%
# A porcentagem de votos no candidato eleito Camilo Santana por município é, então, calculada:

porcentagens_camilo = porcentagem_votos(votos_camilo_por_municipio, votos_totais_por_municipio)

# E os valores são inseridos no dataframe com a criação de uma nova coluna:

votos_camilo_por_municipio['porcentagem_votos'] = porcentagens_camilo
votos_camilo_por_municipio.head()
# Out:
#   nm_municipio  qt_votos  porcentagem_votos
# 0      ABAIARA      4420              74.69
# 1      ACARAPE      5489              54.75
# 2       ACARAÚ     22540              61.38
# 3     ACOPIARA     19132              61.77
# 4       AIUABA      6970              80.48

# %%
# É feito o merge dos dados geoespaciais dos municípios com os indicadores do IBGE:

dados_ibge = pd.merge(
    left= ceara_gpd[['name_muni', 'geometry']], right= dados_ibge,
    how= 'left', left_on= 'name_muni', right_on= 'nome'
)
dados_ibge = dados_ibge.drop('nome', axis= 1) # a coluna nome é retirada, pois é redundante.

# É feito o merge dos dados geoespaciais dos municípios com os dados dos votos no candidato eleito Camilo Santana:

votos_camilo_por_municipio = pd.merge(
    left= ceara_gpd[['name_muni', 'geometry']], right= votos_camilo_por_municipio,
    how= 'left', left_on= 'name_muni', right_on= 'nm_municipio'
)
votos_camilo_por_municipio = votos_camilo_por_municipio.drop('nm_municipio', axis= 1) # a coluna nm_municipio é retirada, pois é redundante.

# %% [markdown]
# ### 4.6.1 Densidade populacional

# %% [markdown]
# O conjunto de dados na coluna `densidade_populacional` é bastante discrepante. O município de Fortaleza concentra mais de 2,5 milhões de habitantes em território modesto, se comparado a outros municípios cearenses. Portanto, aplica-se transformação logarítimica.

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_camilo_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Camilo Santana')
ax2 = dados_ibge.plot(np.log(dados_ibge['densidade_populacional']), cmap= 'Oranges', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Log(Densidade populacional) dos municípios cearenses')
plt.show()

# %% [markdown]
# ### 4.6.2 Indíce de desenvolvimento humano municipal (IDHM)

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_camilo_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Camilo Santana')
ax2 = dados_ibge.plot('idhm', cmap= 'BuGn', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Indíce de desenvolvimento humano nos municípios cearenses')
plt.show()

# %% [markdown]
# ### 4.6.3 PIB *per capita*

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_camilo_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Camilo Santana')
ax2 = dados_ibge.plot(np.log(dados_ibge['pib_per_capita']), cmap= 'YlGn', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Log(PIB per capita) dos municípios cearenses')
plt.show()

# %% [markdown]
# ### 4.6.4 Área urbanizada

# %%
fig, ax = plt.subplots(1, 2, figsize= (14, 10))

ax1 = votos_camilo_por_municipio.plot('porcentagem_votos', legend= True, cmap= 'Reds', legend_kwds= {'shrink': 0.5}, ax= ax[0])
ax1.set_title('Porcentagem de votos do candidato eleito Camilo Santana')
ax2 = dados_ibge.plot(np.log(dados_ibge['porcentagem_urbana']), cmap= 'Purples', legend= True, legend_kwds= {'shrink': 0.5}, ax= ax[1])
ax2.set_title('Log(Porcentagem urbanizada) dos território nos municípios cearenses')
plt.show()

# %% [markdown]
# ## 4.7 Análise por intervalo de indicadores socioeconômicos

# %% [markdown]
# Há a possibilidade de analisar os votos por grupos, intervalos dos indicadores socioeconômicos do IBGE. Instancia-se um *dataframe* com a quantidade de votos para cada candidato em cada município cearense.

# %%
# Os dados são agrupados por nome do município e candidato e os votos somados. Por último, os indíces são resetados:

votos_candidatos_por_municipio = senador.groupby(['nm_municipio', 'nm_votavel'])['qt_votos'].sum().reset_index()
votos_candidatos_por_municipio.head()
# Out:
#   nm_municipio                       nm_votavel  qt_votos
# 0      ABAIARA       CAMILO SOBREIRA DE SANTANA      4420
# 1      ABAIARA           ERIKA GONÇALVES AMORIM        18
# 2      ABAIARA  FRANCISCO CARLOS ALVES DA SILVA         2
# 3      ABAIARA  KAMILA CARDOSO DE SOUZA RIBEIRO       499
# 4      ABAIARA                      VOTO BRANCO       413

# %%
# Os dados socioeconômicos do IBGE são juntados ao dataframe dos votos:

votos_candidatos_por_municipio = pd.merge(
    left= votos_candidatos_por_municipio, right= dados_ibge,
    how= 'left', left_on= 'nm_municipio', right_on= 'name_muni'
)

# A coluna nome é retirada, pois os dados são redundantes:

votos_candidatos_por_municipio = votos_candidatos_por_municipio.drop('name_muni', axis= 1)
votos_candidatos_por_municipio.head()
# Out:
#   nm_municipio                       nm_votavel  qt_votos  \
# 0      ABAIARA       CAMILO SOBREIRA DE SANTANA      4420
# 1      ABAIARA           ERIKA GONÇALVES AMORIM        18
# 2      ABAIARA  FRANCISCO CARLOS ALVES DA SILVA         2
# 3      ABAIARA  KAMILA CARDOSO DE SOUZA RIBEIRO       499
# 4      ABAIARA                      VOTO BRANCO       413
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 2  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 3  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 4  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
# 2      11965  0.628         9158.04             3.19                1.76
# 3      11965  0.628         9158.04             3.19                1.76
# 4      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional
# 0                   66.17
# 1                   66.17
# 2                   66.17
# 3                   66.17
# 4                   66.17

# %% [markdown]
# As funções abaixo serão utilizadas para ajustar os dados para análise:

# %%
def intervalos_ibge(dataframe: pd.DataFrame, nome_coluna: str, nova_coluna: str, bins: list, labels: list):
  '''
  A função 'intervalos_ibge' adiciona ao dataframe com os votos dos candidatos por município uma nova coluna. Tal coluna passa a conter um intervalo
  pré-determinado determinado indicador do IBGE relacionado ao município em questão.

  dataframe: dataframe contendo os votos por candidato em cada município.
  nome_coluna: coluna com a informação que será utilizada para gerar o intervalo.
  nova_coluna: nome da nova coluna contendo os intervalos dos indicadores do IBGE.
  bins: lista com os valores que serão usados para formar os intervalos dos indicadores.
  labels: lista com as labels dos intervalos.
  '''

  dataframe[nova_coluna] = pd.cut(
      dataframe[nome_coluna], bins= bins, labels= labels,
      include_lowest= True, right= False # o valor mais baixo é incluso, enquanto o valor maior não é incluso.
  )

  return dataframe # retorna o dataframe, agora contendo a coluna com os intervalos dos indicadores do IBGE.

def dict_votos_totais(dataframe: pd.DataFrame, coluna_indicador: str):
  '''
  A função dict_votos_totais retorna um dicionário com a quantidade de votos gerais para cada intervalo dos indicadores do IBGE.

  dataframe: contendo os votos por candidato em cada município, além da coluna com os intervalos dos indicadores.
  coluna_indicador: nome da coluna contendo os intervalos dos indicadores.
  '''

  valores_totais = dataframe.groupby(coluna_indicador)['qt_votos'].sum()
  valores_totais = dict(valores_totais)

  return valores_totais

def dataframe_com_porcentagens(dataframe: pd.DataFrame, dictionary: dict, coluna_indicador: str):
  '''
  A função dataframe_com_porcentagens retorna um dataframe contendo a porcentagem de votos para cada candidato referente a cada intervalo de indicador.

  dataframe: dataframe com votos dos candidatos por municípios.
  dictionary: dicionário contendo os votos totais de cada intervalo de indicador do IBGE.
  coluna_indicador: coluna com o indicador do IBGE que se deseja calcular os valores de porcentagem.
  '''

  # O dataframe é agrupado pela coluna com os indicadores e nome dos candidatos, os votos são somados e ordenados:

  dataframe_intervalos_ibge = dataframe.groupby([coluna_indicador, 'nm_votavel'])['qt_votos'].sum()\
                                       .reset_index().sort_values([coluna_indicador, 'qt_votos'], ascending= [True, False])

  # A porcentagem para cada candidado em cada intervalo do indicador é calculada:

  porcentagem = list()

  for index, row in dataframe_intervalos_ibge.iterrows():
    valor = round((row['qt_votos']/dictionary[row[coluna_indicador]]) * 100, 2)
    porcentagem.append(valor)

  # E depois uma nova coluna é adicionada ao dataframe que é retornado:

  dataframe_intervalos_ibge['porcentagem_' + coluna_indicador] = porcentagem # o nome da coluna é obtido a partir da concatenação das strings.

  return dataframe_intervalos_ibge

# %% [markdown]
# ### 4.7.1 Intervalos populacionais

# %%
# Intervalos:

bins = [0, 100000, 500000, 3000000]

# Labels para os intervalos populacionais:

labels = ['Menos de 100 mil habitantes', '100 mil e menos de 500 mil habitantes', '500 mil habitantes ou mais']

# %%
# Uma nova coluna com os intervalos populacionais é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'populacao',
    nova_coluna= 'populacao_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio                  nm_votavel  qt_votos  \
# 0      ABAIARA  CAMILO SOBREIRA DE SANTANA      4420
# 1      ABAIARA      ERIKA GONÇALVES AMORIM        18
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos
# 0                   66.17  Menos de 100 mil habitantes
# 1                   66.17  Menos de 100 mil habitantes

# %%
# Os votos totais para cada intervalo populacional são mostrados no dicionário:

votos_por_intervalo_populacional = dict_votos_totais(votos_candidatos_por_municipio, 'populacao_intervalos')
votos_por_intervalo_populacional
# Out:
# {'Menos de 100 mil habitantes': 3146126,
#  '100 mil e menos de 500 mil habitantes': 917622,
#  '500 mil habitantes ou mais': 1559702}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_populacionais = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_populacional, 'populacao_intervalos'
)
votos_intervalos_populacionais.head()
# Out:
#           populacao_intervalos                       nm_votavel  qt_votos  \
# 0  Menos de 100 mil habitantes       CAMILO SOBREIRA DE SANTANA   2067306
# 3  Menos de 100 mil habitantes  KAMILA CARDOSO DE SOUZA RIBEIRO    548025
# 5  Menos de 100 mil habitantes                        VOTO NULO    252005
# 4  Menos de 100 mil habitantes                      VOTO BRANCO    161536
# 1  Menos de 100 mil habitantes           ERIKA GONÇALVES AMORIM    116365
#
#    porcentagem_populacao_intervalos
# 0                             65.71
# 3                             17.42
# 5                              8.01
# 4                              5.13
# 1                              3.70

# %%
fig = px.bar(
    data_frame= votos_intervalos_populacionais,
    y= 'populacao_intervalos',
    x= 'porcentagem_populacao_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo populacional dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0fb760f9-655c-4cf7-a4d4-b9fe975557ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fb760f9-655c-4cf7-a4d4-b9fe975557ae")) {                    Plotly.newPlot(                        "0fb760f9-655c-4cf7-a4d4-b9fe975557ae",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=CAMILO SOBREIRA DE SANTANA<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"textposition":"auto","x":[65.71,60.37,49.26],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=KAMILA CARDOSO DE SOUZA RIBEIRO<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"textposition":"auto","x":[17.42,22.01,33.55],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[8.01,7.91,8.12],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[5.13,6.24,6.06],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=ERIKA GON\u00c7ALVES AMORIM<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"textposition":"auto","x":[3.7,3.4,2.93],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=FRANCISCO CARLOS ALVES DA SILVA<br>porcentagem_populacao_intervalos=%{x}<br>populacao_intervalos=%{y}<extra></extra>","legendgroup":"FRANCISCO CARLOS ALVES DA SILVA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"FRANCISCO CARLOS ALVES DA SILVA","offsetgroup":"FRANCISCO CARLOS ALVES DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[0.03,0.08,0.08],"xaxis":"x","y":["Menos de 100 mil habitantes","100 mil e menos de 500 mil habitantes","500 mil habitantes ou mais"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0 ...

# %% [markdown]
# > * A porcentagem de votos entre V**OTO BRANCO, VOTO NULO, Erika Gonçalves e no candidato Francisco Carlos** **pouco varia** entre os intervalos referentes as populações.
# * O candidato **Camilo Santana** apresentou **menor desempenho eleitoral** em cidades com **maior população**, apesar de ter aproximadamente 50% dos votos no intervalo das cidades com mais de 500 mil habitantes.
# * Em **nenhum cenário** a candidata **Kamila Cardoso** teve **mais votos** que o candidato eleito, mas observa-se um **melhor desempenho** no cenário das cidades com maior população.

# %% [markdown]
# ### 4.7.2 Intervalos de indíce de desenvolvimento humano

# %%
# Intervalos:

bins = [0, 0.55, 0.7, 0.8]

# Labels para os intervalos de IDH municipal:

labels = ['IDH baixo', 'IDH médio', 'IDH alto']

# %%
# Uma nova coluna com os intervalos de IDHM é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'idhm',
    nova_coluna= 'idhm_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio                  nm_votavel  qt_votos  \
# 0      ABAIARA  CAMILO SOBREIRA DE SANTANA      4420
# 1      ABAIARA      ERIKA GONÇALVES AMORIM        18
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos idhm_intervalos  \
# 0                   66.17  Menos de 100 mil habitantes       IDH médio
# 1                   66.17  Menos de 100 mil habitantes       IDH médio
#
#       pib_intervalos urbana_intervalos
# 0  Menos de R$ 10000      Menos de 10%
# 1  Menos de R$ 10000      Menos de 10%

# %%
# Os votos totais para cada intervalo de IDHM são mostrados no dicionário:

votos_por_intervalo_idhm = dict_votos_totais(votos_candidatos_por_municipio, 'idhm_intervalos')
votos_por_intervalo_idhm
# Out:
# {'IDH baixo': 11019, 'IDH médio': 3804659, 'IDH alto': 1807772}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_idhm = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_idhm, 'idhm_intervalos'
)
votos_intervalos_idhm.head()
# Out:
#   idhm_intervalos                       nm_votavel  qt_votos  \
# 0       IDH baixo       CAMILO SOBREIRA DE SANTANA      6417
# 1       IDH baixo           ERIKA GONÇALVES AMORIM      2798
# 5       IDH baixo                        VOTO NULO       806
# 3       IDH baixo  KAMILA CARDOSO DE SOUZA RIBEIRO       679
# 4       IDH baixo                      VOTO BRANCO       318
#
#    porcentagem_idhm_intervalos
# 0                        58.24
# 1                        25.39
# 5                         7.31
# 3                         6.16
# 4                         2.89

# %%
fig = px.bar(
    data_frame= votos_intervalos_idhm,
    y= 'idhm_intervalos',
    x= 'porcentagem_idhm_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo de IDH municipal dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="266b0a47-c2c7-42fb-bf0a-e66e02d7870f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("266b0a47-c2c7-42fb-bf0a-e66e02d7870f")) {                    Plotly.newPlot(                        "266b0a47-c2c7-42fb-bf0a-e66e02d7870f",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=CAMILO SOBREIRA DE SANTANA<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"textposition":"auto","x":[58.24,64.67,51.03],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=ERIKA GON\u00c7ALVES AMORIM<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"textposition":"auto","x":[25.39,3.71,2.72],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[7.31,8.02,8.05],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=KAMILA CARDOSO DE SOUZA RIBEIRO<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"textposition":"auto","x":[6.16,18.31,31.85],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[2.89,5.24,6.28],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=FRANCISCO CARLOS ALVES DA SILVA<br>porcentagem_idhm_intervalos=%{x}<br>idhm_intervalos=%{y}<extra></extra>","legendgroup":"FRANCISCO CARLOS ALVES DA SILVA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"FRANCISCO CARLOS ALVES DA SILVA","offsetgroup":"FRANCISCO CARLOS ALVES DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[0.01,0.04,0.08],"xaxis":"x","y":["IDH baixo","IDH m\u00e9dio","IDH alto"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewi ...

# %% [markdown]
# > * O intervalo IDH baixo é referente unicamente ao município de Salitre, o que pode ser visto abaixo:

# %%
votos_candidatos_por_municipio.query('idhm_intervalos == "IDH baixo"')['nm_municipio'].unique()
# Out:
# array(['SALITRE'], dtype=object)

# %% [markdown]
# > * E nesse município, em específico, a candidata **Erika Gonçalves teve um desempenho eleitoral significativo.**
# > * O **melhor desempenho** da candidata **Kamila Cardoso** aconteceu no **intervalo de IDH alto.**

# %% [markdown]
# ### 4.7.3 Intervalos de PIB *per capita*

# %%
# Intervalos:

bins = [0, 10000, 20000, 90000]

# Labels para os intervalos de PIB per capita:

labels = ['Menos de R$ 10000', 'Entre R$ 10000 - 19999,99', 'R$ 20000 ou mais']

# %%
# Uma nova coluna com os intervalos de PIB per capita é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'pib_per_capita',
    nova_coluna= 'pib_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio                  nm_votavel  qt_votos  \
# 0      ABAIARA  CAMILO SOBREIRA DE SANTANA      4420
# 1      ABAIARA      ERIKA GONÇALVES AMORIM        18
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos idhm_intervalos  \
# 0                   66.17  Menos de 100 mil habitantes       IDH médio
# 1                   66.17  Menos de 100 mil habitantes       IDH médio
#
#       pib_intervalos urbana_intervalos
# 0  Menos de R$ 10000      Menos de 10%
# 1  Menos de R$ 10000      Menos de 10%

# %%
# Os votos totais para cada intervalo de PIB per capita são mostrados no dicionário:

votos_por_intervalo_pib = dict_votos_totais(votos_candidatos_por_municipio, 'pib_intervalos')
votos_por_intervalo_pib
# Out:
# {'Menos de R$ 10000': 1131888,
#  'Entre R$ 10000 - 19999,99': 2321911,
#  'R$ 20000 ou mais': 2169651}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_pib = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_pib, 'pib_intervalos'
)
votos_intervalos_pib.head()
# Out:
#       pib_intervalos                       nm_votavel  qt_votos  \
# 0  Menos de R$ 10000       CAMILO SOBREIRA DE SANTANA    781105
# 3  Menos de R$ 10000  KAMILA CARDOSO DE SOUZA RIBEIRO    158103
# 5  Menos de R$ 10000                        VOTO NULO     89034
# 1  Menos de R$ 10000           ERIKA GONÇALVES AMORIM     51933
# 4  Menos de R$ 10000                      VOTO BRANCO     51426
#
#    porcentagem_pib_intervalos
# 0                       69.01
# 3                       13.97
# 5                        7.87
# 1                        4.59
# 4                        4.54

# %%
fig = px.bar(
    data_frame= votos_intervalos_pib,
    y= 'pib_intervalos',
    x= 'porcentagem_pib_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo de PIB per capita dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="06b5ea19-6db8-451f-ab89-fc43e9b442ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06b5ea19-6db8-451f-ab89-fc43e9b442ad")) {                    Plotly.newPlot(                        "06b5ea19-6db8-451f-ab89-fc43e9b442ad",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=CAMILO SOBREIRA DE SANTANA<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"textposition":"auto","x":[69.01,65.0,50.66],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=KAMILA CARDOSO DE SOUZA RIBEIRO<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"textposition":"auto","x":[13.97,18.25,31.87],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[7.87,7.91,8.23],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=ERIKA GON\u00c7ALVES AMORIM<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"textposition":"auto","x":[4.59,3.53,2.74],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[4.54,5.27,6.43],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=FRANCISCO CARLOS ALVES DA SILVA<br>porcentagem_pib_intervalos=%{x}<br>pib_intervalos=%{y}<extra></extra>","legendgroup":"FRANCISCO CARLOS ALVES DA SILVA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"FRANCISCO CARLOS ALVES DA SILVA","offsetgroup":"FRANCISCO CARLOS ALVES DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[0.03,0.05,0.07],"xaxis":"x","y":["Menos de R$ 10000","Entre R$ 10000 - 19999,99","R$ 20000 ou mais"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...

# %% [markdown]
# > * Porcentagem dos votos para **VOTO BRANCO, VOTO NULO e na candidata Erika Gonçalvos são próximos para todos os intervalos** do PIB *per capita*.
# > * A porcentagem de votos do candidato eleito **Camilo Santana diminui nos intervalos de maior** PIB *per capita*. Apesar disso, no intervalo de maior PIB o candidato eleito obteve cerca de 50% dos votos.
# * O desempenho eleitoral da candidata Kamila Cardoso cresceu nos intervalos com maior PIB *per capita*.

# %% [markdown]
# ### 4.7.4 Intervalos de território urbanizado

# %%
# Intervalos:

bins= [0, 10, 40, 90]

# Labels para os intervalos de território urbanizado:

labels= ['Menos de 10%', 'Entre 10 - 39,99%', '40% ou mais']

# %%
# Uma nova coluna com os intervalos de território urbanizado é adicionada ao dataframe:

votos_candidatos_por_municipio = intervalos_ibge(
    dataframe= votos_candidatos_por_municipio,
    nome_coluna= 'porcentagem_urbana',
    nova_coluna= 'urbana_intervalos',
    bins= bins, labels= labels
)
votos_candidatos_por_municipio.head(2)
# Out:
#   nm_municipio                  nm_votavel  qt_votos  \
# 0      ABAIARA  CAMILO SOBREIRA DE SANTANA      4420
# 1      ABAIARA      ERIKA GONÇALVES AMORIM        18
#
#                                             geometry  area_territorio  \
# 0  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
# 1  MULTIPOLYGON (((-39.06727 -7.28001, -39.04954 ...          180.833
#
#    populacao   idhm  pib_per_capita  area_urbanizada  porcentagem_urbana  \
# 0      11965  0.628         9158.04             3.19                1.76
# 1      11965  0.628         9158.04             3.19                1.76
#
#    densidade_populacional         populacao_intervalos idhm_intervalos  \
# 0                   66.17  Menos de 100 mil habitantes       IDH médio
# 1                   66.17  Menos de 100 mil habitantes       IDH médio
#
#       pib_intervalos urbana_intervalos
# 0  Menos de R$ 10000      Menos de 10%
# 1  Menos de R$ 10000      Menos de 10%

# %%
# Os votos totais para cada intervalo de território urbanizado são mostrados no dicionário:

votos_por_intervalo_urbana = dict_votos_totais(votos_candidatos_por_municipio, 'urbana_intervalos')
votos_por_intervalo_urbana
# Out:
# {'Menos de 10%': 3608699, 'Entre 10 - 39,99%': 306413, '40% ou mais': 1708338}

# %%
# As porcentagens dos votos para cada candidato em cada município são calculadas e mostradas abaixo:

votos_intervalos_urbana = dataframe_com_porcentagens(
    votos_candidatos_por_municipio, votos_por_intervalo_urbana, 'urbana_intervalos'
)
votos_intervalos_urbana.head()
# Out:
#   urbana_intervalos                       nm_votavel  qt_votos  \
# 0      Menos de 10%       CAMILO SOBREIRA DE SANTANA   2355079
# 3      Menos de 10%  KAMILA CARDOSO DE SOUZA RIBEIRO    630111
# 5      Menos de 10%                        VOTO NULO    288571
# 4      Menos de 10%                      VOTO BRANCO    190792
# 1      Menos de 10%           ERIKA GONÇALVES AMORIM    142819
#
#    porcentagem_urbana_intervalos
# 0                          65.26
# 3                          17.46
# 5                           8.00
# 4                           5.29
# 1                           3.96

# %%
fig = px.bar(
    data_frame= votos_intervalos_urbana,
    y= 'urbana_intervalos',
    x= 'porcentagem_urbana_intervalos',
    color= 'nm_votavel',
    title= 'Porcentagem de votos dos candidatos por intervalo de território urbanizado dos municípios cearenses'
)
fig.update_layout(
    yaxis_title= '', xaxis_title= 'Porcentagem dos votos', legend_title= 'Candidatos',
    yaxis= dict(autorange= 'reversed'), title= dict(x= 0.5)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="398b9a59-44a6-453b-91f3-3d29f92a062e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("398b9a59-44a6-453b-91f3-3d29f92a062e")) {                    Plotly.newPlot(                        "398b9a59-44a6-453b-91f3-3d29f92a062e",                        [{"alignmentgroup":"True","hovertemplate":"nm_votavel=CAMILO SOBREIRA DE SANTANA<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"CAMILO SOBREIRA DE SANTANA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CAMILO SOBREIRA DE SANTANA","offsetgroup":"CAMILO SOBREIRA DE SANTANA","orientation":"h","showlegend":true,"textposition":"auto","x":[65.26,62.56,49.33],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=KAMILA CARDOSO DE SOUZA RIBEIRO<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"KAMILA CARDOSO DE SOUZA RIBEIRO","offsetgroup":"KAMILA CARDOSO DE SOUZA RIBEIRO","orientation":"h","showlegend":true,"textposition":"auto","x":[17.46,23.08,33.51],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO NULO<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"VOTO NULO","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"VOTO NULO","offsetgroup":"VOTO NULO","orientation":"h","showlegend":true,"textposition":"auto","x":[8.0,7.52,8.17],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=VOTO BRANCO<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"VOTO BRANCO","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VOTO BRANCO","offsetgroup":"VOTO BRANCO","orientation":"h","showlegend":true,"textposition":"auto","x":[5.29,5.78,6.13],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=ERIKA GON\u00c7ALVES AMORIM<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"ERIKA GON\u00c7ALVES AMORIM","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ERIKA GON\u00c7ALVES AMORIM","offsetgroup":"ERIKA GON\u00c7ALVES AMORIM","orientation":"h","showlegend":true,"textposition":"auto","x":[3.96,1.0,2.77],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"nm_votavel=FRANCISCO CARLOS ALVES DA SILVA<br>porcentagem_urbana_intervalos=%{x}<br>urbana_intervalos=%{y}<extra></extra>","legendgroup":"FRANCISCO CARLOS ALVES DA SILVA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"FRANCISCO CARLOS ALVES DA SILVA","offsetgroup":"FRANCISCO CARLOS ALVES DA SILVA","orientation":"h","showlegend":true,"textposition":"auto","x":[0.04,0.06,0.08],"xaxis":"x","y":["Menos de 10%","Entre 10 - 39,99%","40% ou mais"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth" ...

# %% [markdown]
# > * **Kamila Cardoso** apresentou **acréscimo na porcentagem de votos nos intervalos com território mais urbanizado.**
# * Já o candidato eleito **Camilo Santana** apresentou **descréscimo na porcentagem de votos nos intervalos com território mais urbanizado.** Porém, no intervalo mais urbanizado ainda obteve cerca de 50% dos votos.
