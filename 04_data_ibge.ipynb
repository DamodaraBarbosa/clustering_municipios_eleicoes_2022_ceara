# %%
import PyPDF2
import io
import pandas as pd

# %%
with open(r'C:\Users\Nityananda\Documents\Python\datacolect\files\ce.pdf', 'rb') as pdf_file:
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    text_data = ''
    for page_num in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_num]
        text_data += page.extract_text()

# %%
df = pd.read_csv(io.StringIO(text_data), sep= '\t')

# %%
df.head(50)
# Out:
#    04/04/2023, 13:58 https://cidades.ibge.gov .br/brasil/sintese/ce?indicadores=29171,47001,30255,95335,29167
# 0   https://cidades.ibge.gov .br/brasil/sintese/ce...
# 1                                               Ceará
# 2                         Municípios GentílicoÁrea da
# 3                                             unidade
# 4                                territorialPopulação
# 5                                   estimadaÍndice de
# 6                                     Desenvolvimento
# 7                                    Humano Municipal
# 8                                       (IDHM)PIB per
# 9                                          capitaÁrea
# 10                                         urbanizada
# 11                  Abaiara cearense 180,833 km²11965
# 12                                pessoas0,6289158,04
# 13                                         R$3,19 km²
# 14                  Acarape cearense 130,002 km²15140
# 15                               pessoas0,60610317,47
# 16                                         R$2,28 km²
# 17                   Acaraú cearense 842,471 km²63556
# 18                               pessoas0,60113261,89
# 19                                        R$16,33 km²
# 20                Acopiara cearense 2254,279 km²54687
# 21                                pessoas0,5959432,25
# 22                                         R$5,46 km²
# 23                  Aiuaba cearense 2438,563 km²17584
# 24                                pessoas0,5698642,90
# 25                                         R$2,07 km²
# 26               Alcântaras cearense 135,760 km²11846
# 27                                pessoas0,6007674,08
# 28                                         R$2,76 km²
# 29  Altaneira cearense 72,675 km² 7712 pessoas 0,6...
# 30                                         R$1,48 km²
# 31              Alto Santo cearense 1147,208 km²16077
# 32                               pessoas0,60111725,03
# 33                                         R$2,10 km²
# 34                Amontada cearense 1175,044 km²44195
# 35                               pessoas0,60612195,24
# 36                                         R$7,55 km²
# 37  Antonina do Norte cearense 259,706 km² 7402 pe...
# 38                                         R$1,50 km²
# 39                 Apuiarés cearense 543,980 km²14742
# 40                                pessoas0,6187642,48
# 41                                         R$2,22 km²
# 42                  Aquiraz cearense 480,236 km²81581
# 43                               pessoas0,64142147,15
# 44                                        R$43,60 km²
# 45                 Aracati cearense 1227,197 km²75392
# 46                               pessoas0,65519713,63
# 47                                        R$19,83 km²
# 48                Aracoiaba cearense 643,988 km²26600
# 49                                pessoas0,6159885,68
